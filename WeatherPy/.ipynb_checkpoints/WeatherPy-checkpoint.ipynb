# %% [markdown]
# ## WeatherPy

# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from citipy import citipy
import seaborn
import random

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# # Generate Cities List

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []
#city_data = []

# Create a set of random lat and lng combinations
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
lng = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lat, lng)

weather_df = pd.DataFrame({"Latitude": lat, "Longitude": lng})
weather_df.head()
# Out:
#     Latitude   Longitude
# 0 -66.478644 -133.636062
# 1 -72.188254   -1.882988
# 2  14.807098 -118.308394
# 3 -31.649533 -174.838528
# 4  44.443122 -140.066500

# %%
#Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #If the city is unique, then add it to a our cities list
    if city not in cities: #city_data:
        cities.append(city)

#Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %% [markdown]
# # Perform API Calls

# %%
 # OpenWeatherMap API Key
api_key = "5e8beccd07c0d11ff6ded6e2aa57281c"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
for x in cities:
        print(x)
# Out:
# rikitea
# hermanus
# cabo san lucas
# vaini
# sitka
# georgetown
# esperance
# nizhneyansk
# hithadhoo
# tombouctou
# baturaja
# svetlogorsk
# ponta do sol
# northam
# sembe
# caimito
# saint george
# san patricio
# destin
# mahebourg
# college
# poum
# mataura
# jamestown
# new norfolk
# bluff
# taolanaro
# petropavlovsk-kamchatskiy
# la ronge
# kelso
# clyde river
# arraial do cabo
# gao
# kahului
# general roca
# bethel
# flinders
# seabra
# boca do acre
# fairbanks
# punta arenas
# busselton
# sao filipe
# illoqqortoormiut
# qaanaaq
# chokurdakh
# torbay
# vostok
# beyneu
# kapaa
# goderich
# puerto ayora
# baykit
# manggar
# bredasdorp
# atuona
# albany
# carnarvon
# castro
# sao joao da barra
# hilo
# ushuaia
# labuhan
# saskylakh
# vaitupu
# komsomolskiy
# nieves
# iqaluit
# daloa
# alindao
# nam tha
# kavieng
# phuket
# srednekolymsk
# port-cartier
# inhambane
# vinh
# upernavik
# norman wells
# orbetello
# belushya guba
# zhigansk
# tasiilaq
# ishigaki
# port elizabeth
# araouane
# port moresby
# wazzan
# provideniya
# kabo
# rocha
# kavaratti
# mount forest
# ligayan
# manzil salim
# ust-ilimsk
# marsh harbour
# lompoc
# joao pinheiro
# longyearbyen
# namibe
# phan rang
# luderitz
# hualmay
# boddam
# rawson
# kosh-agach
# zhezkazgan
# taoudenni
# thomaston
# sigiriya
# karaul
# avarua
# lake havasu city
# yeppoon
# thinadhoo
# port blair
# maldonado
# east london
# kodiak
# cabedelo
# katsuura
# santa fe
# turukhansk
# barrow
# sinnamary
# thompson
# zaraza
# banepa
# butaritari
# port alfred
# ulcinj
# cartagena
# takoradi
# bonito
# vila velha
# bambous virieux
# belaya gora
# bayonet point
# ahipara
# ribeira grande
# avera
# mar del plata
# betioky
# charagua
# nome
# dudinka
# biak
# te anau
# tura
# richards bay
# cape town
# sambava
# linqiong
# ust-karsk
# margate
# ilulissat
# matagami
# galle
# ancud
# aguimes
# laguna
# mogadishu
# antipolo
# hobart
# amudat
# dikson
# nanortalik
# atasu
# zawiercie
# yumen
# mumford
# madimba
# palabuhanratu
# karratha
# hansot
# barawe
# tuktoyaktuk
# hauterive
# yellowknife
# gandajika
# port augusta
# inuvik
# buraydah
# tuatapere
# presidencia roque saenz pena
# swellendam
# yanaul
# samusu
# yatou
# pochutla
# sentyabrskiy
# henties bay
# karanja
# adrar
# tostedt
# bengkulu
# fort nelson
# valparaiso
# bilma
# tanete
# aykhal
# alofi
# anapskaya
# saint-philippe
# kadykchan
# matara
# gat
# domna
# san juan
# broken hill
# slupsk
# khatanga
# gamba
# mys shmidta
# itarema
# platteville
# amderma
# atar
# atagay
# evensk
# geraldton
# ijaki
# pevek
# ocos
# tsihombe
# aklavik
# hovd
# cojumatlan
# natal
# mehamn
# pangnirtung
# olinda
# ullal
# bubaque
# krasnomayskiy
# kutum
# ambon
# menongue
# cayenne
# wairoa
# bajil
# broome
# pemba
# praia da vitoria
# yar-sale
# marabba
# opoczno
# winnemucca
# vieux-habitants
# orlik
# bossangoa
# bubanza
# pangkalanbuun
# berlevag
# attawapiskat
# sandy point
# isla mujeres
# acapulco
# okhotsk
# mandurah
# guilin
# kanonji
# azangaro
# naze
# khormuj
# kawambwa
# sept-iles
# scottsburgh
# dawson creek
# sovetskiy
# airai
# saint-die
# bandar-e torkaman
# santa maria
# barentsburg
# yola
# kirakira
# varena
# padang
# haines junction
# salaga
# port-gentil
# tiksi
# chuy
# isangel
# luanda
# yelizovo
# ternate
# sheridan
# lao cai
# ballina
# rancho palos verdes
# novikovo
# dwarka
# yulara
# voyvozh
# tual
# finschhafen
# acarau
# pouebo
# tolbazy
# pacific grove
# aden
# sakakah
# husavik
# barra dos coqueiros
# conceicao do coite
# geilo
# tumannyy
# farsund
# beringovskiy
# sinop
# dunedin
# nikolskoye
# filingue
# cockburn harbour
# vila franca do campo
# mareeba
# lebu
# hasaki
# qasigiannguit
# severo-kurilsk
# tefe
# kruisfontein
# kudahuvadhoo
# murbad
# lata
# bartica
# san cristobal
# kaitangata
# colares
# clearlake
# yabrud
# pangody
# makakilo city
# dire dawa
# marzuq
# kargasok
# de-kastri
# khotynets
# karkaralinsk
# mindelo
# lysa hora
# jinchengjiang
# marshfield
# faanui
# paamiut
# ca mau
# mutsamudu
# saint-paul
# olga
# kamalpur
# sumbawa
# jumla
# bacolod
# zaria
# charters towers
# sinnai
# lavrentiya
# himatnagar
# gardan diwal
# oksfjord
# ust-kamchatsk
# monte carmelo
# constitucion
# lakes entrance
# bucerias
# linxia
# aleksandrovskiy zavod
# palmas
# chapais
# kapuskasing
# ramasukha
# tigil
# talara
# quelimane
# noumea
# garissa
# kiunga
# nanlong
# taseyevo
# nguiu
# morondava
# lengshuitan
# grenfell
# gold coast
# medina
# abay
# vila
# hobyo
# saleaula
# sosnovo-ozerskoye
# braedstrup
# jardim
# faya
# lagos
# strelna
# narsaq
# mbini
# cherskiy
# ust-tsilma
# churapcha
# loreto
# eyl
# shirokiy
# bykovo
# sitio novo do tocantins
# cidreira
# banjar
# concepcion del oro
# naryan-mar
# taicheng
# havoysund
# uglegorsk
# ho
# elko
# grand river south east
# yunjinghong
# hihifo
# ullapool
# coihaique
# byron bay
# medicine hat
# axim
# lorengau
# ippy
# helmsdale
# ormara
# lojt kirkeby
# carutapera
# bilibino
# katherine
# hami
# miyakonojo
# romilly-sur-seine
# arman
# wilmington
# segezha
# kabanjahe
# codrington
# moree
# anadyr
# burkhala
# saint-joseph
# torrington
# pietarsaari
# humaita
# xam nua
# warqla
# novita
# nautla
# pisco
# kamenka
# grindavik
# aswan
# port macquarie
# victoria
# fortuna
# talaya
# nago
# pandan
# skibbereen
# dogondoutchi
# puerto rondon
# umea
# mormugao
# dodoma
# zharkent
# miri
# pombas
# carndonagh
# port hardy
# granadilla de abona
# beloha
# hambantota
# luba
# rio cuarto
# dubrovnik
# marsaxlokk
# khonuu
# stoyba
# viedma
# zhongshu
# panama city
# vardo
# ferme-neuve
# majene
# tessalit
# mpophomeni
# wanning
# warrnambool
# lososina
# harwich
# nova vicosa
# perth
# coahuayana
# tlaxiaco
# saint anthony
# amapa
# eenhana
# panjab
# mnogovershinnyy
# maniitsoq
# sulam
# quatre cocos
# qingdao
# kanganpur
# port lincoln
# mecca
# brae
# paravakar
# caravelas
# necochea
# hofn
# north myrtle beach
# jacareacanga
# cabinda
# jiddah
# tabialan
# harlingen
# hannibal
# sangueya
# surok
# guerrero negro
# benghazi
# straumen
# suoyarvi
# verkhnyaya inta
# dingle
# chunan
# caraballeda
# sorvag
# bar harbor
# verkhoyansk
# joshimath
# takaka
# el alto
# balancan
# leh
# aksarka
# selfoss
# kaohsiung
# souillac
# alta floresta
# bonavista
# anloga
# niksar
# sisimiut
# bermeo
# rungata
# libreville
# lamar
# bathsheba
# durban
# harderwijk
# tabas
# waitati
# seoul
# moberly
# eureka
# iralaya
# togur
# helena
# lolua
# alice springs
# emba
# gizo
# along
# grand-santi
# angoram
# buin
# sisophon
# freeport
# yei
# vangaindrano
# belmonte
# shiyan
# vagur
# monte alegre de sergipe
# vao
# asbestos
# solnechnyy
# toccoa
# challapata
# ixtapa
# high rock
# talnakh
# khorixas
# sistranda
# raton
# benguela
# itamaraca
# uray
# kijang
# tamandare
# banda aceh
# turayf
# nuevitas
# hikari
# oranjestad
# muhlhausen
# luang prabang
# adamas
# mayumba
# portobelo
# dvur kralove
# keuruu
# nizhnyaya tura
# pangai
# la rioja
# saldanha
# camana
# tunduma
# paradwip
# portland
# sola
# batouri
# tatarsk
# balaguer
# arona
# mongar
# nishihara
# ignacio de la llave
# turiacu
# sijunjung
# xingcheng
# inderborskiy
# puerto del rosario
# bishop auckland
# gombe
# venice
# vanimo
# opuwo

# %%
# Build query URL
query_url = url + "&q=" + city

# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

#print(f"The weather API responded with: {weather_json}.")

# Create counters
record_count = 1
set_count = 1
units = "imperial"

city_data = []

# Loop through the list of cities and perform a request for data on each
# Loop through all the cities in our list

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

         # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
       
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
    record_count += 1
    
    time.sleep(0.05)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 3 of Set 1 | hermanus
# Processing Record 5 of Set 1 | cabo san lucas
# Processing Record 7 of Set 1 | vaini
# Processing Record 9 of Set 1 | sitka
# Processing Record 11 of Set 1 | georgetown
# Processing Record 13 of Set 1 | esperance
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | tombouctou
# Processing Record 21 of Set 1 | baturaja
# Processing Record 23 of Set 1 | svetlogorsk
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | northam
# Processing Record 29 of Set 1 | sembe
# City not found. Skipping...
# Processing Record 31 of Set 1 | caimito
# Processing Record 33 of Set 1 | saint george
# Processing Record 35 of Set 1 | san patricio
# Processing Record 37 of Set 1 | destin
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | college
# Processing Record 43 of Set 1 | poum
# Processing Record 45 of Set 1 | mataura
# Processing Record 47 of Set 1 | jamestown
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 51 of Set 1 | bluff
# Processing Record 53 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 55 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 57 of Set 1 | la ronge
# Processing Record 59 of Set 1 | kelso
# Processing Record 61 of Set 1 | clyde river
# Processing Record 63 of Set 1 | arraial do cabo
# Processing Record 65 of Set 1 | gao
# Processing Record 67 of Set 1 | kahului
# Processing Record 69 of Set 1 | general roca
# Processing Record 71 of Set 1 | bethel
# Processing Record 73 of Set 1 | flinders
# Processing Record 75 of Set 1 | seabra
# Processing Record 77 of Set 1 | boca do acre
# Processing Record 79 of Set 1 | fairbanks
# Processing Record 81 of Set 1 | punta arenas
# Processing Record 83 of Set 1 | busselton
# Processing Record 85 of Set 1 | sao filipe
# Processing Record 87 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 89 of Set 1 | qaanaaq
# Processing Record 91 of Set 1 | chokurdakh
# Processing Record 93 of Set 1 | torbay
# Processing Record 95 of Set 1 | vostok
# Processing Record 97 of Set 1 | beyneu
# Processing Record 99 of Set 1 | kapaa
# Processing Record 0 of Set 2 | goderich
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | baykit
# Processing Record 6 of Set 2 | manggar
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | atuona
# Processing Record 12 of Set 2 | albany
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | castro
# Processing Record 18 of Set 2 | sao joao da barra
# Processing Record 20 of Set 2 | hilo
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | labuhan
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 2 | komsomolskiy
# Processing Record 32 of Set 2 | nieves
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | daloa
# Processing Record 38 of Set 2 | alindao
# Processing Record 40 of Set 2 | nam tha
# City not found. Skipping...
# Processing Record 42 of Set 2 | kavieng
# Processing Record 44 of Set 2 | phuket
# Processing Record 46 of Set 2 | srednekolymsk
# Processing Record 48 of Set 2 | port-cartier
# Processing Record 50 of Set 2 | inhambane
# Processing Record 52 of Set 2 | vinh
# Processing Record 54 of Set 2 | upernavik
# Processing Record 56 of Set 2 | norman wells
# Processing Record 58 of Set 2 | orbetello
# Processing Record 60 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 62 of Set 2 | zhigansk
# Processing Record 64 of Set 2 | tasiilaq
# Processing Record 66 of Set 2 | ishigaki
# Processing Record 68 of Set 2 | port elizabeth
# Processing Record 70 of Set 2 | araouane
# Processing Record 72 of Set 2 | port moresby
# Processing Record 74 of Set 2 | wazzan
# City not found. Skipping...
# Processing Record 76 of Set 2 | provideniya
# Processing Record 78 of Set 2 | kabo
# Processing Record 80 of Set 2 | rocha
# Processing Record 82 of Set 2 | kavaratti
# Processing Record 84 of Set 2 | mount forest
# Processing Record 86 of Set 2 | ligayan
# Processing Record 88 of Set 2 | manzil salim
# Processing Record 90 of Set 2 | ust-ilimsk
# Processing Record 92 of Set 2 | marsh harbour
# Processing Record 94 of Set 2 | lompoc
# Processing Record 96 of Set 2 | joao pinheiro
# Processing Record 98 of Set 2 | longyearbyen
# Processing Record 0 of Set 3 | namibe
# Processing Record 2 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 3 | luderitz
# Processing Record 6 of Set 3 | hualmay
# Processing Record 8 of Set 3 | boddam
# Processing Record 10 of Set 3 | rawson
# Processing Record 12 of Set 3 | kosh-agach
# Processing Record 14 of Set 3 | zhezkazgan
# Processing Record 16 of Set 3 | taoudenni
# Processing Record 18 of Set 3 | thomaston
# Processing Record 20 of Set 3 | sigiriya
# Processing Record 22 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 3 | avarua
# Processing Record 26 of Set 3 | lake havasu city
# Processing Record 28 of Set 3 | yeppoon
# Processing Record 30 of Set 3 | thinadhoo
# Processing Record 32 of Set 3 | port blair
# Processing Record 34 of Set 3 | maldonado
# Processing Record 36 of Set 3 | east london
# Processing Record 38 of Set 3 | kodiak
# Processing Record 40 of Set 3 | cabedelo
# Processing Record 42 of Set 3 | katsuura
# Processing Record 44 of Set 3 | santa fe
# Processing Record 46 of Set 3 | turukhansk
# Processing Record 48 of Set 3 | barrow
# Processing Record 50 of Set 3 | sinnamary
# Processing Record 52 of Set 3 | thompson
# Processing Record 54 of Set 3 | zaraza
# Processing Record 56 of Set 3 | banepa
# Processing Record 58 of Set 3 | butaritari
# Processing Record 60 of Set 3 | port alfred
# Processing Record 62 of Set 3 | ulcinj
# Processing Record 64 of Set 3 | cartagena
# Processing Record 66 of Set 3 | takoradi
# Processing Record 68 of Set 3 | bonito
# Processing Record 70 of Set 3 | vila velha
# Processing Record 72 of Set 3 | bambous virieux
# Processing Record 74 of Set 3 | belaya gora
# Processing Record 76 of Set 3 | bayonet point
# Processing Record 78 of Set 3 | ahipara
# Processing Record 80 of Set 3 | ribeira grande
# Processing Record 82 of Set 3 | avera
# Processing Record 84 of Set 3 | mar del plata
# Processing Record 86 of Set 3 | betioky
# City not found. Skipping...
# Processing Record 88 of Set 3 | charagua
# Processing Record 90 of Set 3 | nome
# Processing Record 92 of Set 3 | dudinka
# Processing Record 94 of Set 3 | biak
# Processing Record 96 of Set 3 | te anau
# Processing Record 98 of Set 3 | tura
# Processing Record 0 of Set 4 | richards bay
# Processing Record 2 of Set 4 | cape town
# Processing Record 4 of Set 4 | sambava
# Processing Record 6 of Set 4 | linqiong
# Processing Record 8 of Set 4 | ust-karsk
# Processing Record 10 of Set 4 | margate
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 14 of Set 4 | matagami
# Processing Record 16 of Set 4 | galle
# Processing Record 18 of Set 4 | ancud
# Processing Record 20 of Set 4 | aguimes
# Processing Record 22 of Set 4 | laguna
# Processing Record 24 of Set 4 | mogadishu
# Processing Record 26 of Set 4 | antipolo
# Processing Record 28 of Set 4 | hobart
# Processing Record 30 of Set 4 | amudat
# Processing Record 32 of Set 4 | dikson
# Processing Record 34 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | atasu
# Processing Record 38 of Set 4 | zawiercie
# Processing Record 40 of Set 4 | yumen
# Processing Record 42 of Set 4 | mumford
# Processing Record 44 of Set 4 | madimba
# Processing Record 46 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 4 | karratha
# Processing Record 50 of Set 4 | hansot
# Processing Record 52 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 54 of Set 4 | tuktoyaktuk
# Processing Record 56 of Set 4 | hauterive
# Processing Record 58 of Set 4 | yellowknife
# Processing Record 60 of Set 4 | gandajika
# Processing Record 62 of Set 4 | port augusta
# Processing Record 64 of Set 4 | inuvik
# Processing Record 66 of Set 4 | buraydah
# Processing Record 68 of Set 4 | tuatapere
# Processing Record 70 of Set 4 | presidencia roque saenz pena
# Processing Record 72 of Set 4 | swellendam
# Processing Record 74 of Set 4 | yanaul
# Processing Record 76 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 78 of Set 4 | yatou
# Processing Record 80 of Set 4 | pochutla
# Processing Record 82 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 84 of Set 4 | henties bay
# Processing Record 86 of Set 4 | karanja
# Processing Record 88 of Set 4 | adrar
# Processing Record 90 of Set 4 | tostedt
# Processing Record 92 of Set 4 | bengkulu
# City not found. Skipping...
# Processing Record 94 of Set 4 | fort nelson
# Processing Record 96 of Set 4 | valparaiso
# Processing Record 98 of Set 4 | bilma
# Processing Record 0 of Set 5 | tanete
# Processing Record 2 of Set 5 | aykhal
# Processing Record 4 of Set 5 | alofi
# Processing Record 6 of Set 5 | anapskaya
# Processing Record 8 of Set 5 | saint-philippe
# Processing Record 10 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 5 | matara
# Processing Record 14 of Set 5 | gat
# Processing Record 16 of Set 5 | domna
# Processing Record 18 of Set 5 | san juan
# Processing Record 20 of Set 5 | broken hill
# Processing Record 22 of Set 5 | slupsk
# Processing Record 24 of Set 5 | khatanga
# Processing Record 26 of Set 5 | gamba
# Processing Record 28 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 5 | itarema
# Processing Record 32 of Set 5 | platteville
# Processing Record 34 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | atar
# Processing Record 38 of Set 5 | atagay
# Processing Record 40 of Set 5 | evensk
# Processing Record 42 of Set 5 | geraldton
# Processing Record 44 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 5 | pevek
# Processing Record 48 of Set 5 | ocos
# Processing Record 50 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 52 of Set 5 | aklavik
# Processing Record 54 of Set 5 | hovd
# Processing Record 56 of Set 5 | cojumatlan
# City not found. Skipping...
# Processing Record 58 of Set 5 | natal
# Processing Record 60 of Set 5 | mehamn
# Processing Record 62 of Set 5 | pangnirtung
# Processing Record 64 of Set 5 | olinda
# Processing Record 66 of Set 5 | ullal
# Processing Record 68 of Set 5 | bubaque
# Processing Record 70 of Set 5 | krasnomayskiy
# Processing Record 72 of Set 5 | kutum
# Processing Record 74 of Set 5 | ambon
# Processing Record 76 of Set 5 | menongue
# Processing Record 78 of Set 5 | cayenne
# Processing Record 80 of Set 5 | wairoa
# Processing Record 82 of Set 5 | bajil
# Processing Record 84 of Set 5 | broome
# Processing Record 86 of Set 5 | pemba
# Processing Record 88 of Set 5 | praia da vitoria
# Processing Record 90 of Set 5 | yar-sale
# Processing Record 92 of Set 5 | marabba
# Processing Record 94 of Set 5 | opoczno
# Processing Record 96 of Set 5 | winnemucca
# Processing Record 98 of Set 5 | vieux-habitants
# Processing Record 0 of Set 6 | orlik
# Processing Record 2 of Set 6 | bossangoa
# Processing Record 4 of Set 6 | bubanza
# Processing Record 6 of Set 6 | pangkalanbuun
# Processing Record 8 of Set 6 | berlevag
# Processing Record 10 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 6 | sandy point
# Processing Record 14 of Set 6 | isla mujeres
# Processing Record 16 of Set 6 | acapulco
# Processing Record 18 of Set 6 | okhotsk
# Processing Record 20 of Set 6 | mandurah
# Processing Record 22 of Set 6 | guilin
# Processing Record 24 of Set 6 | kanonji
# Processing Record 26 of Set 6 | azangaro
# Processing Record 28 of Set 6 | naze
# Processing Record 30 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 32 of Set 6 | kawambwa
# Processing Record 34 of Set 6 | sept-iles
# Processing Record 36 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 38 of Set 6 | dawson creek
# Processing Record 40 of Set 6 | sovetskiy
# Processing Record 42 of Set 6 | airai
# Processing Record 44 of Set 6 | saint-die
# City not found. Skipping...
# Processing Record 46 of Set 6 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 48 of Set 6 | santa maria
# Processing Record 50 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 52 of Set 6 | yola
# Processing Record 54 of Set 6 | kirakira
# Processing Record 56 of Set 6 | varena
# Processing Record 58 of Set 6 | padang
# Processing Record 60 of Set 6 | haines junction
# Processing Record 62 of Set 6 | salaga
# Processing Record 64 of Set 6 | port-gentil
# Processing Record 66 of Set 6 | tiksi
# Processing Record 68 of Set 6 | chuy
# Processing Record 70 of Set 6 | isangel
# Processing Record 72 of Set 6 | luanda
# Processing Record 74 of Set 6 | yelizovo
# Processing Record 76 of Set 6 | ternate
# Processing Record 78 of Set 6 | sheridan
# Processing Record 80 of Set 6 | lao cai
# Processing Record 82 of Set 6 | ballina
# Processing Record 84 of Set 6 | rancho palos verdes
# Processing Record 86 of Set 6 | novikovo
# Processing Record 88 of Set 6 | dwarka
# Processing Record 90 of Set 6 | yulara
# Processing Record 92 of Set 6 | voyvozh
# Processing Record 94 of Set 6 | tual
# Processing Record 96 of Set 6 | finschhafen
# Processing Record 98 of Set 6 | acarau
# City not found. Skipping...
# Processing Record 0 of Set 7 | pouebo
# Processing Record 2 of Set 7 | tolbazy
# Processing Record 4 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | aden
# Processing Record 8 of Set 7 | sakakah
# City not found. Skipping...
# Processing Record 10 of Set 7 | husavik
# Processing Record 12 of Set 7 | barra dos coqueiros
# Processing Record 14 of Set 7 | conceicao do coite
# Processing Record 16 of Set 7 | geilo
# Processing Record 18 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 7 | farsund
# Processing Record 22 of Set 7 | beringovskiy
# Processing Record 24 of Set 7 | sinop
# Processing Record 26 of Set 7 | dunedin
# Processing Record 28 of Set 7 | nikolskoye
# Processing Record 30 of Set 7 | filingue
# Processing Record 32 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 7 | vila franca do campo
# Processing Record 36 of Set 7 | mareeba
# Processing Record 38 of Set 7 | lebu
# Processing Record 40 of Set 7 | hasaki
# Processing Record 42 of Set 7 | qasigiannguit
# Processing Record 44 of Set 7 | severo-kurilsk
# Processing Record 46 of Set 7 | tefe
# Processing Record 48 of Set 7 | kruisfontein
# Processing Record 50 of Set 7 | kudahuvadhoo
# Processing Record 52 of Set 7 | murbad
# Processing Record 54 of Set 7 | lata
# Processing Record 56 of Set 7 | bartica
# Processing Record 58 of Set 7 | san cristobal
# Processing Record 60 of Set 7 | kaitangata
# Processing Record 62 of Set 7 | colares
# Processing Record 64 of Set 7 | clearlake
# Processing Record 66 of Set 7 | yabrud
# Processing Record 68 of Set 7 | pangody
# Processing Record 70 of Set 7 | makakilo city
# Processing Record 72 of Set 7 | dire dawa
# Processing Record 74 of Set 7 | marzuq
# Processing Record 76 of Set 7 | kargasok
# Processing Record 78 of Set 7 | de-kastri
# Processing Record 80 of Set 7 | khotynets
# Processing Record 82 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 84 of Set 7 | mindelo
# Processing Record 86 of Set 7 | lysa hora
# Processing Record 88 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 90 of Set 7 | marshfield
# Processing Record 92 of Set 7 | faanui
# Processing Record 94 of Set 7 | paamiut
# Processing Record 96 of Set 7 | ca mau
# Processing Record 98 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 0 of Set 8 | saint-paul
# Processing Record 2 of Set 8 | olga
# Processing Record 4 of Set 8 | kamalpur
# Processing Record 6 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 8 of Set 8 | jumla
# Processing Record 10 of Set 8 | bacolod
# Processing Record 12 of Set 8 | zaria
# Processing Record 14 of Set 8 | charters towers
# Processing Record 16 of Set 8 | sinnai
# Processing Record 18 of Set 8 | lavrentiya
# Processing Record 20 of Set 8 | himatnagar
# Processing Record 22 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 24 of Set 8 | oksfjord
# Processing Record 26 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 8 | monte carmelo
# Processing Record 30 of Set 8 | constitucion
# Processing Record 32 of Set 8 | lakes entrance
# Processing Record 34 of Set 8 | bucerias
# Processing Record 36 of Set 8 | linxia
# Processing Record 38 of Set 8 | aleksandrovskiy zavod
# Processing Record 40 of Set 8 | palmas
# Processing Record 42 of Set 8 | chapais
# Processing Record 44 of Set 8 | kapuskasing
# Processing Record 46 of Set 8 | ramasukha
# City not found. Skipping...
# Processing Record 48 of Set 8 | tigil
# Processing Record 50 of Set 8 | talara
# Processing Record 52 of Set 8 | quelimane
# Processing Record 54 of Set 8 | noumea
# Processing Record 56 of Set 8 | garissa
# Processing Record 58 of Set 8 | kiunga
# Processing Record 60 of Set 8 | nanlong
# Processing Record 62 of Set 8 | taseyevo
# Processing Record 64 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 66 of Set 8 | morondava
# Processing Record 68 of Set 8 | lengshuitan
# Processing Record 70 of Set 8 | grenfell
# Processing Record 72 of Set 8 | gold coast
# Processing Record 74 of Set 8 | medina
# Processing Record 76 of Set 8 | abay
# Processing Record 78 of Set 8 | vila
# Processing Record 80 of Set 8 | hobyo
# Processing Record 82 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 84 of Set 8 | sosnovo-ozerskoye
# Processing Record 86 of Set 8 | braedstrup
# Processing Record 88 of Set 8 | jardim
# Processing Record 90 of Set 8 | faya
# Processing Record 92 of Set 8 | lagos
# Processing Record 94 of Set 8 | strelna
# Processing Record 96 of Set 8 | narsaq
# Processing Record 98 of Set 8 | mbini
# Processing Record 0 of Set 9 | cherskiy
# Processing Record 2 of Set 9 | ust-tsilma
# Processing Record 4 of Set 9 | churapcha
# Processing Record 6 of Set 9 | loreto
# Processing Record 8 of Set 9 | eyl
# Processing Record 10 of Set 9 | shirokiy
# Processing Record 12 of Set 9 | bykovo
# Processing Record 14 of Set 9 | sitio novo do tocantins
# City not found. Skipping...
# Processing Record 16 of Set 9 | cidreira
# Processing Record 18 of Set 9 | banjar
# Processing Record 20 of Set 9 | concepcion del oro
# Processing Record 22 of Set 9 | naryan-mar
# Processing Record 24 of Set 9 | taicheng
# Processing Record 26 of Set 9 | havoysund
# Processing Record 28 of Set 9 | uglegorsk
# Processing Record 30 of Set 9 | ho
# City not found. Skipping...
# Processing Record 32 of Set 9 | elko
# Processing Record 34 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 38 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 9 | ullapool
# Processing Record 42 of Set 9 | coihaique
# Processing Record 44 of Set 9 | byron bay
# Processing Record 46 of Set 9 | medicine hat
# Processing Record 48 of Set 9 | axim
# Processing Record 50 of Set 9 | lorengau
# Processing Record 52 of Set 9 | ippy
# Processing Record 54 of Set 9 | helmsdale
# Processing Record 56 of Set 9 | ormara
# Processing Record 58 of Set 9 | lojt kirkeby
# Processing Record 60 of Set 9 | carutapera
# Processing Record 62 of Set 9 | bilibino
# Processing Record 64 of Set 9 | katherine
# Processing Record 66 of Set 9 | hami
# Processing Record 68 of Set 9 | miyakonojo
# Processing Record 70 of Set 9 | romilly-sur-seine
# Processing Record 72 of Set 9 | arman
# Processing Record 74 of Set 9 | wilmington
# Processing Record 76 of Set 9 | segezha
# Processing Record 78 of Set 9 | kabanjahe
# Processing Record 80 of Set 9 | codrington
# Processing Record 82 of Set 9 | moree
# Processing Record 84 of Set 9 | anadyr
# Processing Record 86 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 88 of Set 9 | saint-joseph
# Processing Record 90 of Set 9 | torrington
# Processing Record 92 of Set 9 | pietarsaari
# City not found. Skipping...
# Processing Record 94 of Set 9 | humaita
# Processing Record 96 of Set 9 | xam nua
# Processing Record 98 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 0 of Set 10 | novita
# Processing Record 2 of Set 10 | nautla
# Processing Record 4 of Set 10 | pisco
# Processing Record 6 of Set 10 | kamenka
# Processing Record 8 of Set 10 | grindavik
# Processing Record 10 of Set 10 | aswan
# Processing Record 12 of Set 10 | port macquarie
# Processing Record 14 of Set 10 | victoria
# Processing Record 16 of Set 10 | fortuna
# Processing Record 18 of Set 10 | talaya
# Processing Record 20 of Set 10 | nago
# Processing Record 22 of Set 10 | pandan
# Processing Record 24 of Set 10 | skibbereen
# Processing Record 26 of Set 10 | dogondoutchi
# Processing Record 28 of Set 10 | puerto rondon
# Processing Record 30 of Set 10 | umea
# Processing Record 32 of Set 10 | mormugao
# City not found. Skipping...
# Processing Record 34 of Set 10 | dodoma
# Processing Record 36 of Set 10 | zharkent
# Processing Record 38 of Set 10 | miri
# Processing Record 40 of Set 10 | pombas
# Processing Record 42 of Set 10 | carndonagh
# Processing Record 44 of Set 10 | port hardy
# Processing Record 46 of Set 10 | granadilla de abona
# Processing Record 48 of Set 10 | beloha
# Processing Record 50 of Set 10 | hambantota
# Processing Record 52 of Set 10 | luba
# Processing Record 54 of Set 10 | rio cuarto
# Processing Record 56 of Set 10 | dubrovnik
# Processing Record 58 of Set 10 | marsaxlokk
# Processing Record 60 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 62 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 64 of Set 10 | viedma
# Processing Record 66 of Set 10 | zhongshu
# Processing Record 68 of Set 10 | panama city
# Processing Record 70 of Set 10 | vardo
# Processing Record 72 of Set 10 | ferme-neuve
# Processing Record 74 of Set 10 | majene
# Processing Record 76 of Set 10 | tessalit
# Processing Record 78 of Set 10 | mpophomeni
# Processing Record 80 of Set 10 | wanning
# Processing Record 82 of Set 10 | warrnambool
# Processing Record 84 of Set 10 | lososina
# Processing Record 86 of Set 10 | harwich
# Processing Record 88 of Set 10 | nova vicosa
# Processing Record 90 of Set 10 | perth
# Processing Record 92 of Set 10 | coahuayana
# Processing Record 94 of Set 10 | tlaxiaco
# City not found. Skipping...
# Processing Record 96 of Set 10 | saint anthony
# Processing Record 98 of Set 10 | amapa
# Processing Record 0 of Set 11 | eenhana
# Processing Record 2 of Set 11 | panjab
# Processing Record 4 of Set 11 | mnogovershinnyy
# Processing Record 6 of Set 11 | maniitsoq
# Processing Record 8 of Set 11 | sulam
# Processing Record 10 of Set 11 | quatre cocos
# Processing Record 12 of Set 11 | qingdao
# Processing Record 14 of Set 11 | kanganpur
# Processing Record 16 of Set 11 | port lincoln
# Processing Record 18 of Set 11 | mecca
# Processing Record 20 of Set 11 | brae
# Processing Record 22 of Set 11 | paravakar
# City not found. Skipping...
# Processing Record 24 of Set 11 | caravelas
# Processing Record 26 of Set 11 | necochea
# Processing Record 28 of Set 11 | hofn
# Processing Record 30 of Set 11 | north myrtle beach
# Processing Record 32 of Set 11 | jacareacanga
# Processing Record 34 of Set 11 | cabinda
# Processing Record 36 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 40 of Set 11 | harlingen
# Processing Record 42 of Set 11 | hannibal
# Processing Record 44 of Set 11 | sangueya
# Processing Record 46 of Set 11 | surok
# Processing Record 48 of Set 11 | guerrero negro
# Processing Record 50 of Set 11 | benghazi
# Processing Record 52 of Set 11 | straumen
# Processing Record 54 of Set 11 | suoyarvi
# Processing Record 56 of Set 11 | verkhnyaya inta
# Processing Record 58 of Set 11 | dingle
# Processing Record 60 of Set 11 | chunan
# Processing Record 62 of Set 11 | caraballeda
# Processing Record 64 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 66 of Set 11 | bar harbor
# Processing Record 68 of Set 11 | verkhoyansk
# Processing Record 70 of Set 11 | joshimath
# Processing Record 72 of Set 11 | takaka
# Processing Record 74 of Set 11 | el alto
# Processing Record 76 of Set 11 | balancan
# City not found. Skipping...
# Processing Record 78 of Set 11 | leh
# Processing Record 80 of Set 11 | aksarka
# Processing Record 82 of Set 11 | selfoss
# Processing Record 84 of Set 11 | kaohsiung
# Processing Record 86 of Set 11 | souillac
# Processing Record 88 of Set 11 | alta floresta
# Processing Record 90 of Set 11 | bonavista
# Processing Record 92 of Set 11 | anloga
# Processing Record 94 of Set 11 | niksar
# Processing Record 96 of Set 11 | sisimiut
# Processing Record 98 of Set 11 | bermeo
# Processing Record 0 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 12 | libreville
# Processing Record 4 of Set 12 | lamar
# Processing Record 6 of Set 12 | bathsheba
# Processing Record 8 of Set 12 | durban
# Processing Record 10 of Set 12 | harderwijk
# Processing Record 12 of Set 12 | tabas
# Processing Record 14 of Set 12 | waitati
# Processing Record 16 of Set 12 | seoul
# Processing Record 18 of Set 12 | moberly
# Processing Record 20 of Set 12 | eureka
# Processing Record 22 of Set 12 | iralaya
# Processing Record 24 of Set 12 | togur
# Processing Record 26 of Set 12 | helena
# Processing Record 28 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 12 | alice springs
# Processing Record 32 of Set 12 | emba
# Processing Record 34 of Set 12 | gizo
# Processing Record 36 of Set 12 | along
# Processing Record 38 of Set 12 | grand-santi
# Processing Record 40 of Set 12 | angoram
# Processing Record 42 of Set 12 | buin
# Processing Record 44 of Set 12 | sisophon
# Processing Record 46 of Set 12 | freeport
# Processing Record 48 of Set 12 | yei
# City not found. Skipping...
# Processing Record 50 of Set 12 | vangaindrano
# Processing Record 52 of Set 12 | belmonte
# Processing Record 54 of Set 12 | shiyan
# Processing Record 56 of Set 12 | vagur
# Processing Record 58 of Set 12 | monte alegre de sergipe
# Processing Record 60 of Set 12 | vao
# Processing Record 62 of Set 12 | asbestos
# Processing Record 64 of Set 12 | solnechnyy
# Processing Record 66 of Set 12 | toccoa
# Processing Record 68 of Set 12 | challapata
# Processing Record 70 of Set 12 | ixtapa
# Processing Record 72 of Set 12 | high rock
# Processing Record 74 of Set 12 | talnakh
# Processing Record 76 of Set 12 | khorixas
# Processing Record 78 of Set 12 | sistranda
# Processing Record 80 of Set 12 | raton
# Processing Record 82 of Set 12 | benguela
# Processing Record 84 of Set 12 | itamaraca
# Processing Record 86 of Set 12 | uray
# Processing Record 88 of Set 12 | kijang
# Processing Record 90 of Set 12 | tamandare
# Processing Record 92 of Set 12 | banda aceh
# Processing Record 94 of Set 12 | turayf
# Processing Record 96 of Set 12 | nuevitas
# Processing Record 98 of Set 12 | hikari
# Processing Record 0 of Set 13 | oranjestad
# Processing Record 2 of Set 13 | muhlhausen
# Processing Record 4 of Set 13 | luang prabang
# Processing Record 6 of Set 13 | adamas
# Processing Record 8 of Set 13 | mayumba
# Processing Record 10 of Set 13 | portobelo
# Processing Record 12 of Set 13 | dvur kralove
# City not found. Skipping...
# Processing Record 14 of Set 13 | keuruu
# Processing Record 16 of Set 13 | nizhnyaya tura
# Processing Record 18 of Set 13 | pangai
# Processing Record 20 of Set 13 | la rioja
# Processing Record 22 of Set 13 | saldanha
# Processing Record 24 of Set 13 | camana
# City not found. Skipping...
# Processing Record 26 of Set 13 | tunduma
# Processing Record 28 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 13 | portland
# Processing Record 32 of Set 13 | sola
# Processing Record 34 of Set 13 | batouri
# Processing Record 36 of Set 13 | tatarsk
# Processing Record 38 of Set 13 | balaguer
# Processing Record 40 of Set 13 | arona
# Processing Record 42 of Set 13 | mongar
# Processing Record 44 of Set 13 | nishihara
# Processing Record 46 of Set 13 | ignacio de la llave
# Processing Record 48 of Set 13 | turiacu
# Processing Record 50 of Set 13 | sijunjung
# Processing Record 52 of Set 13 | xingcheng
# Processing Record 54 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 56 of Set 13 | puerto del rosario
# Processing Record 58 of Set 13 | bishop auckland
# Processing Record 60 of Set 13 | gombe
# Processing Record 62 of Set 13 | venice
# Processing Record 64 of Set 13 | vanimo
# Processing Record 66 of Set 13 | opuwo

# %%
city_data
# Out:
# [{'City': 'rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 76.42,
#   'Humidity': 94,
#   'Cloudiness': 44,
#   'Wind Speed': 17.49,
#   'Country': 'PF',
#   'Date': 1533143102},
#  {'City': 'hermanus',
#   'Lat': -34.42,
#   'Lng': 19.24,
#   'Max Temp': 45.01,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 2.62,
#   'Country': 'ZA',
#   'Date': 1533143102},
#  {'City': 'cabo san lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 93.2,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'MX',
#   'Date': 1533141900},
#  {'City': 'vaini',
#   'Lat': 15.34,
#   'Lng': 74.49,
#   'Max Temp': 69.31,
#   'Humidity': 99,
#   'Cloudiness': 92,
#   'Wind Speed': 6.2,
#   'Country': 'IN',
#   'Date': 1533143103},
#  {'City': 'sitka',
#   'Lat': 37.17,
#   'Lng': -99.65,
#   'Max Temp': 85.24,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 10.45,
#   'Country': 'US',
#   'Date': 1533143103},
#  {'City': 'georgetown',
#   'Lat': 6.8,
#   'Lng': -58.16,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'GY',
#   'Date': 1533139980},
#  {'City': 'esperance',
#   'Lat': 10.24,
#   'Lng': -61.45,
#   'Max Temp': 74.53,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 2.73,
#   'Country': 'TT',
#   'Date': 1533143104},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 83.44,
#   'Humidity': 100,
#   'Cloudiness': 64,
#   'Wind Speed': 9.22,
#   'Country': 'MV',
#   'Date': 1533143105},
#  {'City': 'tombouctou',
#   'Lat': 16.77,
#   'Lng': -3.01,
#   'Max Temp': 90.46,
#   'Humidity': 44,
#   'Cloudiness': 24,
#   'Wind Speed': 10.11,
#   'Country': 'ML',
#   'Date': 1533143105},
#  {'City': 'baturaja',
#   'Lat': -4.12,
#   'Lng': 104.17,
#   'Max Temp': 71.74,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 3.06,
#   'Country': 'ID',
#   'Date': 1533143105},
#  {'City': 'svetlogorsk',
#   'Lat': 53.14,
#   'Lng': 59.15,
#   'Max Temp': 68,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Date': 1533141000},
#  {'City': 'ponta do sol',
#   'Lat': -20.63,
#   'Lng': -46,
#   'Max Temp': 75.25,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.97,
#   'Country': 'BR',
#   'Date': 1533143106},
#  {'City': 'northam',
#   'Lat': 51.04,
#   'Lng': -4.21,
#   'Max Temp': 69.8,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'GB',
#   'Date': 1533140400},
#  {'City': 'caimito',
#   'Lat': 22.95,
#   'Lng': -82.6,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CU',
#   'Date': 1533142500},
#  {'City': 'saint george',
#   'Lat': 39.45,
#   'Lng': 22.34,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'GR',
#   'Date': 1533142200},
#  {'City': 'san patricio',
#   'Lat': -26.98,
#   'Lng': -56.83,
#   'Max Temp': 65.08,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18,
#   'Country': 'PY',
#   'Date': 1533143107},
#  {'City': 'destin',
#   'Lat': 30.39,
#   'Lng': -86.5,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 4.41,
#   'Country': 'US',
#   'Date': 1533141720},
#  {'City': 'mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'MU',
#   'Date': 1533139200},
#  {'City': 'college',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 66.2,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': 1533139080},
#  {'City': 'poum',
#   'Lat': 41.28,
#   'Lng': 20.71,
#   'Max Temp': 73.4,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'MK',
#   'Date': 1533141000},
#  {'City': 'mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 38.62,
#   'Humidity': 93,
#   'Cloudiness': 48,
#   'Wind Speed': 4.74,
#   'Country': 'NZ',
#   'Date': 1533143109},
#  {'City': 'jamestown',
#   'Lat': -33.21,
#   'Lng': 138.6,
#   'Max Temp': 46.81,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 12.57,
#   'Country': 'AU',
#   'Date': 1533143109},
#  {'City': 'new norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 37.4,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': 1533141000},
#  {'City': 'bluff',
#   'Lat': -23.58,
#   'Lng': 149.07,
#   'Max Temp': 41.32,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 2.62,
#   'Country': 'AU',
#   'Date': 1533143110},
#  {'City': 'petropavlovsk-kamchatskiy',
#   'Lat': 53.05,
#   'Lng': 158.65,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Date': 1533139200},
#  {'City': 'la ronge',
#   'Lat': 55.1,
#   'Lng': -105.3,
#   'Max Temp': 66.2,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'kelso',
#   'Lat': 46.14,
#   'Lng': -122.91,
#   'Max Temp': 64.4,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': 1533141300},
#  {'City': 'clyde river',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 35.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': 1533139980},
#  {'City': 'arraial do cabo',
#   'Lat': -22.97,
#   'Lng': -42.02,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'BR',
#   'Date': 1533139200},
#  {'City': 'gao',
#   'Lat': 16.28,
#   'Lng': -0.04,
#   'Max Temp': 94.78,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 2.95,
#   'Country': 'ML',
#   'Date': 1533143112},
#  {'City': 'kahului',
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 20.8,
#   'Country': 'US',
#   'Date': 1533139200},
#  {'City': 'general roca',
#   'Lat': -39.03,
#   'Lng': -67.58,
#   'Max Temp': 48.2,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AR',
#   'Date': 1533139200},
#  {'City': 'bethel',
#   'Lat': 60.79,
#   'Lng': -161.76,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 18.34,
#   'Country': 'US',
#   'Date': 1533138780},
#  {'City': 'flinders',
#   'Lat': -34.58,
#   'Lng': 150.85,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'AU',
#   'Date': 1533139200},
#  {'City': 'seabra',
#   'Lat': -12.42,
#   'Lng': -41.77,
#   'Max Temp': 86,
#   'Humidity': 37,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'BR',
#   'Date': 1533139200},
#  {'City': 'boca do acre',
#   'Lat': -8.76,
#   'Lng': -67.39,
#   'Max Temp': 78.85,
#   'Humidity': 90,
#   'Cloudiness': 92,
#   'Wind Speed': 2.62,
#   'Country': 'BR',
#   'Date': 1533143114},
#  {'City': 'fairbanks',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 66.2,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': 1533139080},
#  {'City': 'punta arenas',
#   'Lat': -53.16,
#   'Lng': -70.91,
#   'Max Temp': 44.6,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'CL',
#   'Date': 1533139200},
#  {'City': 'busselton',
#   'Lat': -33.64,
#   'Lng': 115.35,
#   'Max Temp': 55.09,
#   'Humidity': 100,
#   'Cloudiness': 24,
#   'Wind Speed': 30.69,
#   'Country': 'AU',
#   'Date': 1533143115},
#  {'City': 'sao filipe',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 80.47,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 0.38,
#   'Country': 'CV',
#   'Date': 1533143115},
#  {'City': 'qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 39.34,
#   'Humidity': 93,
#   'Cloudiness': 24,
#   'Wind Speed': 5.53,
#   'Country': 'GL',
#   'Date': 1533143116},
#  {'City': 'chokurdakh',
#   'Lat': 70.62,
#   'Lng': 147.9,
#   'Max Temp': 40.51,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 6.2,
#   'Country': 'RU',
#   'Date': 1533143116},
#  {'City': 'torbay',
#   'Lat': 47.66,
#   'Lng': -52.73,
#   'Max Temp': 82.4,
#   'Humidity': 39,
#   'Cloudiness': 5,
#   'Wind Speed': 13.87,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'vostok',
#   'Lat': 46.45,
#   'Lng': 135.83,
#   'Max Temp': 53.56,
#   'Humidity': 89,
#   'Cloudiness': 8,
#   'Wind Speed': 2.17,
#   'Country': 'RU',
#   'Date': 1533143117},
#  {'City': 'beyneu',
#   'Lat': 45.32,
#   'Lng': 55.19,
#   'Max Temp': 82.09,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 14.47,
#   'Country': 'KZ',
#   'Date': 1533143117},
#  {'City': 'kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': 1533138960},
#  {'City': 'goderich',
#   'Lat': 43.74,
#   'Lng': -81.71,
#   'Max Temp': 67.87,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 16.26,
#   'Country': 'CA',
#   'Date': 1533143118},
#  {'City': 'puerto ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 73.27,
#   'Humidity': 91,
#   'Cloudiness': 32,
#   'Wind Speed': 16.04,
#   'Country': 'EC',
#   'Date': 1533143104},
#  {'City': 'baykit',
#   'Lat': 61.68,
#   'Lng': 96.39,
#   'Max Temp': 42.76,
#   'Humidity': 96,
#   'Cloudiness': 0,
#   'Wind Speed': 3.18,
#   'Country': 'RU',
#   'Date': 1533143118},
#  {'City': 'manggar',
#   'Lat': -2.88,
#   'Lng': 108.27,
#   'Max Temp': 75.52,
#   'Humidity': 100,
#   'Cloudiness': 32,
#   'Wind Speed': 5.08,
#   'Country': 'ID',
#   'Date': 1533143119},
#  {'City': 'bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 62.6,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'ZA',
#   'Date': 1533139200},
#  {'City': 'atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 78.04,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 17.16,
#   'Country': 'PF',
#   'Date': 1533143119},
#  {'City': 'albany',
#   'Lat': 42.65,
#   'Lng': -73.75,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': 1533142320},
#  {'City': 'carnarvon',
#   'Lat': -30.97,
#   'Lng': 22.13,
#   'Max Temp': 39.7,
#   'Humidity': 67,
#   'Cloudiness': 8,
#   'Wind Speed': 4.18,
#   'Country': 'ZA',
#   'Date': 1533143120},
#  {'City': 'castro',
#   'Lat': -42.48,
#   'Lng': -73.76,
#   'Max Temp': 49.24,
#   'Humidity': 80,
#   'Cloudiness': 24,
#   'Wind Speed': 2.39,
#   'Country': 'CL',
#   'Date': 1533143121},
#  {'City': 'sao joao da barra',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'BR',
#   'Date': 1533139200},
#  {'City': 'hilo',
#   'Lat': 19.71,
#   'Lng': -155.08,
#   'Max Temp': 73.4,
#   'Humidity': 51,
#   'Cloudiness': 1,
#   'Wind Speed': 12.75,
#   'Country': 'US',
#   'Date': 1533141600},
#  {'City': 'ushuaia',
#   'Lat': -54.81,
#   'Lng': -68.31,
#   'Max Temp': 42.8,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 23.04,
#   'Country': 'AR',
#   'Date': 1533139200},
#  {'City': 'labuhan',
#   'Lat': -2.54,
#   'Lng': 115.51,
#   'Max Temp': 69.49,
#   'Humidity': 99,
#   'Cloudiness': 92,
#   'Wind Speed': 0.72,
#   'Country': 'ID',
#   'Date': 1533143122},
#  {'City': 'saskylakh',
#   'Lat': 71.97,
#   'Lng': 114.09,
#   'Max Temp': 47.8,
#   'Humidity': 71,
#   'Cloudiness': 88,
#   'Wind Speed': 13.13,
#   'Country': 'RU',
#   'Date': 1533143122},
#  {'City': 'komsomolskiy',
#   'Lat': 67.55,
#   'Lng': 63.78,
#   'Max Temp': 43.12,
#   'Humidity': 56,
#   'Cloudiness': 24,
#   'Wind Speed': 6.2,
#   'Country': 'RU',
#   'Date': 1533143123},
#  {'City': 'nieves',
#   'Lat': 24,
#   'Lng': -103.02,
#   'Max Temp': 75.61,
#   'Humidity': 53,
#   'Cloudiness': 24,
#   'Wind Speed': 5.19,
#   'Country': 'MX',
#   'Date': 1533143124},
#  {'City': 'iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.52,
#   'Max Temp': 44.6,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'daloa',
#   'Lat': 6.88,
#   'Lng': -6.45,
#   'Max Temp': 84.07,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 3.96,
#   'Country': 'CI',
#   'Date': 1533143043},
#  {'City': 'alindao',
#   'Lat': 5.04,
#   'Lng': 21.21,
#   'Max Temp': 69.49,
#   'Humidity': 97,
#   'Cloudiness': 88,
#   'Wind Speed': 6.64,
#   'Country': 'CF',
#   'Date': 1533143125},
#  {'City': 'kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 76.06,
#   'Humidity': 100,
#   'Cloudiness': 88,
#   'Wind Speed': 1.39,
#   'Country': 'PG',
#   'Date': 1533143125},
#  {'City': 'phuket',
#   'Lat': 7.89,
#   'Lng': 98.4,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Country': 'TH',
#   'Date': 1533141000},
#  {'City': 'srednekolymsk',
#   'Lat': 67.46,
#   'Lng': 153.71,
#   'Max Temp': 56.26,
#   'Humidity': 88,
#   'Cloudiness': 92,
#   'Wind Speed': 3.18,
#   'Country': 'RU',
#   'Date': 1533143126},
#  {'City': 'port-cartier',
#   'Lat': 50.03,
#   'Lng': -66.88,
#   'Max Temp': 75.2,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'inhambane',
#   'Lat': -23.87,
#   'Lng': 35.38,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'MZ',
#   'Date': 1533139200},
#  {'City': 'vinh',
#   'Lat': 18.67,
#   'Lng': 105.69,
#   'Max Temp': 82.54,
#   'Humidity': 73,
#   'Cloudiness': 36,
#   'Wind Speed': 7.09,
#   'Country': 'VN',
#   'Date': 1533143127},
#  {'City': 'upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 42.31,
#   'Humidity': 86,
#   'Cloudiness': 80,
#   'Wind Speed': 6.76,
#   'Country': 'GL',
#   'Date': 1533143127},
#  {'City': 'norman wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'orbetello',
#   'Lat': 42.44,
#   'Lng': 11.21,
#   'Max Temp': 98.6,
#   'Humidity': 39,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Country': 'IT',
#   'Date': 1533138900},
#  {'City': 'zhigansk',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': 56.44,
#   'Humidity': 84,
#   'Cloudiness': 12,
#   'Wind Speed': 2.51,
#   'Country': 'RU',
#   'Date': 1533143128},
#  {'City': 'tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'GL',
#   'Date': 1533138600},
#  {'City': 'ishigaki',
#   'Lat': 24.34,
#   'Lng': 124.16,
#   'Max Temp': 85.69,
#   'Humidity': 97,
#   'Cloudiness': 56,
#   'Wind Speed': 11.01,
#   'Country': 'JP',
#   'Date': 1533143129},
#  {'City': 'port elizabeth',
#   'Lat': 39.31,
#   'Lng': -74.98,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': 1533142500},
#  {'City': 'araouane',
#   'Lat': 18.9,
#   'Lng': -3.53,
#   'Max Temp': 102.16,
#   'Humidity': 21,
#   'Cloudiness': 80,
#   'Wind Speed': 7.43,
#   'Country': 'ML',
#   'Date': 1533143129},
#  {'City': 'port moresby',
#   'Lat': -9.47,
#   'Lng': 147.16,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'PG',
#   'Date': 1533139200},
#  {'City': 'provideniya',
#   'Lat': 64.42,
#   'Lng': -173.23,
#   'Max Temp': 51.22,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 3.06,
#   'Country': 'RU',
#   'Date': 1533143131},
#  {'City': 'kabo',
#   'Lat': 7.69,
#   'Lng': 18.62,
#   'Max Temp': 71.2,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 6.53,
#   'Country': 'CF',
#   'Date': 1533143131},
#  {'City': 'rocha',
#   'Lat': -34.48,
#   'Lng': -54.34,
#   'Max Temp': 51.04,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.52,
#   'Country': 'UY',
#   'Date': 1533143131},
#  {'City': 'kavaratti',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 81.1,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 13.69,
#   'Country': 'IN',
#   'Date': 1533143132},
#  {'City': 'mount forest',
#   'Lat': 43.98,
#   'Lng': -80.74,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 17.22,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'ligayan',
#   'Lat': 4.65,
#   'Lng': 119.47,
#   'Max Temp': 81.01,
#   'Humidity': 100,
#   'Cloudiness': 68,
#   'Wind Speed': 18.5,
#   'Country': 'PH',
#   'Date': 1533143132},
#  {'City': 'manzil salim',
#   'Lat': 35.86,
#   'Lng': 8.48,
#   'Max Temp': 84.2,
#   'Humidity': 39,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'TN',
#   'Date': 1533139200},
#  {'City': 'ust-ilimsk',
#   'Lat': 57.96,
#   'Lng': 102.73,
#   'Max Temp': 56.89,
#   'Humidity': 83,
#   'Cloudiness': 80,
#   'Wind Speed': 3.74,
#   'Country': 'RU',
#   'Date': 1533143133},
#  {'City': 'marsh harbour',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 85.33,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 14.7,
#   'Country': 'BS',
#   'Date': 1533143133},
#  {'City': 'lompoc',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 3.51,
#   'Country': 'US',
#   'Date': 1533141300},
#  {'City': 'joao pinheiro',
#   'Lat': -17.74,
#   'Lng': -46.17,
#   'Max Temp': 85.15,
#   'Humidity': 42,
#   'Cloudiness': 32,
#   'Wind Speed': 2.73,
#   'Country': 'BR',
#   'Date': 1533143134},
#  {'City': 'longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.63,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'NO',
#   'Date': 1533140400},
#  {'City': 'namibe',
#   'Lat': -15.19,
#   'Lng': 12.15,
#   'Max Temp': 65.17,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 10.45,
#   'Country': 'AO',
#   'Date': 1533143134},
#  {'City': 'luderitz',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 54.64,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'NA',
#   'Date': 1533143135},
#  {'City': 'hualmay',
#   'Lat': -11.1,
#   'Lng': -77.61,
#   'Max Temp': 72.19,
#   'Humidity': 64,
#   'Cloudiness': 32,
#   'Wind Speed': 5.53,
#   'Country': 'PE',
#   'Date': 1533143135},
#  {'City': 'boddam',
#   'Lat': 57.47,
#   'Lng': -1.78,
#   'Max Temp': 64.4,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'GB',
#   'Date': 1533140400},
#  {'City': 'rawson',
#   'Lat': -43.3,
#   'Lng': -65.11,
#   'Max Temp': 55.72,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 9.44,
#   'Country': 'AR',
#   'Date': 1533143136},
#  {'City': 'kosh-agach',
#   'Lat': 49.99,
#   'Lng': 88.66,
#   'Max Temp': 44.29,
#   'Humidity': 88,
#   'Cloudiness': 56,
#   'Wind Speed': 2.39,
#   'Country': 'RU',
#   'Date': 1533143136},
#  {'City': 'zhezkazgan',
#   'Lat': 47.8,
#   'Lng': 67.71,
#   'Max Temp': 68.23,
#   'Humidity': 53,
#   'Cloudiness': 36,
#   'Wind Speed': 7.2,
#   'Country': 'KZ',
#   'Date': 1533143137},
#  {'City': 'taoudenni',
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 108.55,
#   'Humidity': 10,
#   'Cloudiness': 12,
#   'Wind Speed': 6.76,
#   'Country': 'ML',
#   'Date': 1533143137},
#  {'City': 'thomaston',
#   'Lat': 32.89,
#   'Lng': -84.33,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': 1533141300},
#  {'City': 'sigiriya',
#   'Lat': 7.95,
#   'Lng': 80.75,
#   'Max Temp': 79.57,
#   'Humidity': 67,
#   'Cloudiness': 68,
#   'Wind Speed': 12.01,
#   'Country': 'LK',
#   'Date': 1533143138},
#  {'City': 'avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'CK',
#   'Date': 1533139200},
#  {'City': 'lake havasu city',
#   'Lat': 34.47,
#   'Lng': -114.34,
#   'Max Temp': 100.4,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 12.75,
#   'Country': 'US',
#   'Date': 1533141300},
#  {'City': 'yeppoon',
#   'Lat': -23.13,
#   'Lng': 150.74,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.18,
#   'Country': 'AU',
#   'Date': 1533141000},
#  {'City': 'thinadhoo',
#   'Lat': 0.53,
#   'Lng': 72.93,
#   'Max Temp': 84.07,
#   'Humidity': 100,
#   'Cloudiness': 88,
#   'Wind Speed': 7.54,
#   'Country': 'MV',
#   'Date': 1533143139},
#  {'City': 'port blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 80.65,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 22.53,
#   'Country': 'IN',
#   'Date': 1533143140},
#  {'City': 'maldonado',
#   'Lat': -34.91,
#   'Lng': -54.96,
#   'Max Temp': 50,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'UY',
#   'Date': 1533139200},
#  {'City': 'east london',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 17.22,
#   'Country': 'ZA',
#   'Date': 1533139200},
#  {'City': 'kodiak',
#   'Lat': 39.95,
#   'Lng': -94.76,
#   'Max Temp': 82.4,
#   'Humidity': 48,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': 1533142380},
#  {'City': 'cabedelo',
#   'Lat': -6.97,
#   'Lng': -34.84,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'BR',
#   'Date': 1533139200},
#  {'City': 'katsuura',
#   'Lat': 33.93,
#   'Lng': 134.5,
#   'Max Temp': 77.59,
#   'Humidity': 86,
#   'Cloudiness': 12,
#   'Wind Speed': 3.51,
#   'Country': 'JP',
#   'Date': 1533143141},
#  {'City': 'santa fe',
#   'Lat': -31.62,
#   'Lng': -60.7,
#   'Max Temp': 56.8,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'AR',
#   'Date': 1533143142},
#  {'City': 'turukhansk',
#   'Lat': 65.8,
#   'Lng': 87.96,
#   'Max Temp': 41.41,
#   'Humidity': 90,
#   'Cloudiness': 80,
#   'Wind Speed': 10.22,
#   'Country': 'RU',
#   'Date': 1533143142},
#  {'City': 'barrow',
#   'Lat': -38.31,
#   'Lng': -60.23,
#   'Max Temp': 51.31,
#   'Humidity': 48,
#   'Cloudiness': 68,
#   'Wind Speed': 13.8,
#   'Country': 'AR',
#   'Date': 1533143142},
#  {'City': 'sinnamary',
#   'Lat': 5.38,
#   'Lng': -52.96,
#   'Max Temp': 83.26,
#   'Humidity': 91,
#   'Cloudiness': 12,
#   'Wind Speed': 10.78,
#   'Country': 'GF',
#   'Date': 1533143143},
#  {'City': 'thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 64.4,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'zaraza',
#   'Lat': 9.35,
#   'Lng': -65.33,
#   'Max Temp': 73.18,
#   'Humidity': 100,
#   'Cloudiness': 88,
#   'Wind Speed': 6.98,
#   'Country': 'VE',
#   'Date': 1533143143},
#  {'City': 'banepa',
#   'Lat': 27.63,
#   'Lng': 85.52,
#   'Max Temp': 69.8,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 1.61,
#   'Country': 'NP',
#   'Date': 1533142200},
#  {'City': 'butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 83.26,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 5.41,
#   'Country': 'KI',
#   'Date': 1533143144},
#  {'City': 'port alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 62.11,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 19.06,
#   'Country': 'ZA',
#   'Date': 1533142993},
#  {'City': 'ulcinj',
#   'Lat': 41.93,
#   'Lng': 19.22,
#   'Max Temp': 87.8,
#   'Humidity': 43,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'ME',
#   'Date': 1533141000},
#  {'City': 'cartagena',
#   'Lat': 37.63,
#   'Lng': -1,
#   'Max Temp': 96.8,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'ES',
#   'Date': 1533141000},
#  {'City': 'takoradi',
#   'Lat': 4.89,
#   'Lng': -1.75,
#   'Max Temp': 77.68,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 9.78,
#   'Country': 'GH',
#   'Date': 1533143145},
#  {'City': 'bonito',
#   'Lat': -1.36,
#   'Lng': -47.3,
#   'Max Temp': 83.44,
#   'Humidity': 81,
#   'Cloudiness': 48,
#   'Wind Speed': 10.56,
#   'Country': 'BR',
#   'Date': 1533143145},
#  {'City': 'vila velha',
#   'Lat': -3.71,
#   'Lng': -38.6,
#   'Max Temp': 84.2,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 20.8,
#   'Country': 'BR',
#   'Date': 1533139200},
#  {'City': 'bambous virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'MU',
#   'Date': 1533139200},
#  {'City': 'belaya gora',
#   'Lat': 68.54,
#   'Lng': 146.19,
#   'Max Temp': 44.47,
#   'Humidity': 92,
#   'Cloudiness': 24,
#   'Wind Speed': 3.18,
#   'Country': 'RU',
#   'Date': 1533143147},
#  {'City': 'bayonet point',
#   'Lat': 28.33,
#   'Lng': -82.68,
#   'Max Temp': 89.6,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': 1533141780},
#  {'City': 'ahipara',
#   'Lat': -35.17,
#   'Lng': 173.16,
#   'Max Temp': 43.03,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'NZ',
#   'Date': 1533143147},
#  {'City': 'ribeira grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'PT',
#   'Date': 1533141000},
#  {'City': 'avera',
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Max Temp': 86,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': 1533141360},
#  {'City': 'mar del plata',
#   'Lat': -46.43,
#   'Lng': -67.52,
#   'Max Temp': 53.29,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 10.22,
#   'Country': 'AR',
#   'Date': 1533142879},
#  {'City': 'charagua',
#   'Lat': -19.79,
#   'Lng': -63.2,
#   'Max Temp': 64.4,
#   'Humidity': 39,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'BO',
#   'Date': 1533139200},
#  {'City': 'nome',
#   'Lat': 30.04,
#   'Lng': -94.42,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': 1533141300},
#  {'City': 'dudinka',
#   'Lat': 69.41,
#   'Lng': 86.18,
#   'Max Temp': 45.64,
#   'Humidity': 62,
#   'Cloudiness': 68,
#   'Wind Speed': 21.52,
#   'Country': 'RU',
#   'Date': 1533143149},
#  {'City': 'biak',
#   'Lat': -0.91,
#   'Lng': 122.88,
#   'Max Temp': 74.98,
#   'Humidity': 98,
#   'Cloudiness': 36,
#   'Wind Speed': 6.08,
#   'Country': 'ID',
#   'Date': 1533143149},
#  {'City': 'te anau',
#   'Lat': -45.41,
#   'Lng': 167.72,
#   'Max Temp': 34.03,
#   'Humidity': 92,
#   'Cloudiness': 32,
#   'Wind Speed': 2.39,
#   'Country': 'NZ',
#   'Date': 1533143150},
#  {'City': 'tura',
#   'Lat': 25.52,
#   'Lng': 90.21,
#   'Max Temp': 73.99,
#   'Humidity': 98,
#   'Cloudiness': 92,
#   'Wind Speed': 3.51,
#   'Country': 'IN',
#   'Date': 1533143150},
#  {'City': 'richards bay',
#   'Lat': -28.77,
#   'Lng': 32.06,
#   'Max Temp': 65.8,
#   'Humidity': 80,
#   'Cloudiness': 12,
#   'Wind Speed': 11.01,
#   'Country': 'ZA',
#   'Date': 1533143150},
#  {'City': 'cape town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 57.2,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'ZA',
#   'Date': 1533139200},
#  {'City': 'sambava',
#   'Lat': -14.27,
#   'Lng': 50.17,
#   'Max Temp': 72.73,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 11.01,
#   'Country': 'MG',
#   'Date': 1533143151},
#  {'City': 'linqiong',
#   'Lat': 30.42,
#   'Lng': 103.46,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'CN',
#   'Date': 1533139200},
#  {'City': 'ust-karsk',
#   'Lat': 52.71,
#   'Lng': 118.82,
#   'Max Temp': 59.14,
#   'Humidity': 90,
#   'Cloudiness': 12,
#   'Wind Speed': 2.17,
#   'Country': 'RU',
#   'Date': 1533143151},
#  {'City': 'margate',
#   'Lat': -43.03,
#   'Lng': 147.26,
#   'Max Temp': 37.4,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': 1533141000},
#  {'City': 'ilulissat',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': 46.4,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'GL',
#   'Date': 1533138600},
#  {'City': 'matagami',
#   'Lat': 9.67,
#   'Lng': 8.4,
#   'Max Temp': 67.42,
#   'Humidity': 97,
#   'Cloudiness': 92,
#   'Wind Speed': 3.4,
#   'Country': 'NG',
#   'Date': 1533143152},
#  {'City': 'galle',
#   'Lat': 29.74,
#   'Lng': -97.91,
#   'Max Temp': 89.6,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': 1533138960},
#  {'City': 'ancud',
#   'Lat': -41.87,
#   'Lng': -73.83,
#   'Max Temp': 50.5,
#   'Humidity': 75,
#   'Cloudiness': 8,
#   'Wind Speed': 0.49,
#   'Country': 'CL',
#   'Date': 1533143153},
#  {'City': 'aguimes',
#   'Lat': 27.91,
#   'Lng': -15.45,
#   'Max Temp': 80.6,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 28.86,
#   'Country': 'ES',
#   'Date': 1533141000},
#  {'City': 'laguna',
#   'Lat': 27.52,
#   'Lng': -110.01,
#   'Max Temp': 91.4,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 2.51,
#   'Country': 'MX',
#   'Date': 1533141720},
#  {'City': 'mogadishu',
#   'Lat': 2.04,
#   'Lng': 45.34,
#   'Max Temp': 77.77,
#   'Humidity': 98,
#   'Cloudiness': 92,
#   'Wind Speed': 18.84,
#   'Country': 'SO',
#   'Date': 1533143154},
#  {'City': 'antipolo',
#   'Lat': 14.59,
#   'Lng': 121.18,
#   'Max Temp': 82.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'PH',
#   'Date': 1533139200},
#  {'City': 'hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 37.4,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': 1533141000},
#  {'City': 'amudat',
#   'Lat': 1.95,
#   'Lng': 34.95,
#   'Max Temp': 60.4,
#   'Humidity': 93,
#   'Cloudiness': 8,
#   'Wind Speed': 2.17,
#   'Country': 'UG',
#   'Date': 1533143155},
#  {'City': 'dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 36.82,
#   'Humidity': 100,
#   'Cloudiness': 32,
#   'Wind Speed': 17.6,
#   'Country': 'RU',
#   'Date': 1533143155},
#  {'City': 'nanortalik',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 41.5,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62,
#   'Country': 'GL',
#   'Date': 1533143156},
#  {'City': 'atasu',
#   'Lat': 48.68,
#   'Lng': 71.64,
#   'Max Temp': 69.31,
#   'Humidity': 58,
#   'Cloudiness': 92,
#   'Wind Speed': 10.45,
#   'Country': 'KZ',
#   'Date': 1533143156},
#  {'City': 'zawiercie',
#   'Lat': 50.48,
#   'Lng': 19.43,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'PL',
#   'Date': 1533141000},
#  {'City': 'yumen',
#   'Lat': 40.29,
#   'Lng': 97.04,
#   'Max Temp': 67.24,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 8.43,
#   'Country': 'CN',
#   'Date': 1533143156},
#  {'City': 'mumford',
#   'Lat': 5.26,
#   'Lng': -0.76,
#   'Max Temp': 78.76,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'GH',
#   'Date': 1533143157},
#  {'City': 'madimba',
#   'Lat': 4.42,
#   'Lng': 9.93,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'CM',
#   'Date': 1533139200},
#  {'City': 'karratha',
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 60.94,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 16.71,
#   'Country': 'AU',
#   'Date': 1533142915},
#  {'City': 'hansot',
#   'Lat': 21.59,
#   'Lng': 72.81,
#   'Max Temp': 80.47,
#   'Humidity': 96,
#   'Cloudiness': 24,
#   'Wind Speed': 18.05,
#   'Country': 'IN',
#   'Date': 1533143030},
#  {'City': 'tuktoyaktuk',
#   'Lat': 69.44,
#   'Lng': -133.03,
#   'Max Temp': 41,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': 1533141420},
#  {'City': 'hauterive',
#   'Lat': 46.09,
#   'Lng': 3.45,
#   'Max Temp': 89.6,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'FR',
#   'Date': 1533141000},
#  {'City': 'yellowknife',
#   'Lat': 62.45,
#   'Lng': -114.38,
#   'Max Temp': 68,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'gandajika',
#   'Lat': -6.75,
#   'Lng': 23.95,
#   'Max Temp': 74.44,
#   'Humidity': 65,
#   'Cloudiness': 12,
#   'Wind Speed': 6.76,
#   'Country': 'CD',
#   'Date': 1533143159},
#  {'City': 'port augusta',
#   'Lat': -32.49,
#   'Lng': 137.76,
#   'Max Temp': 42.8,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'AU',
#   'Date': 1533139200},
#  {'City': 'inuvik',
#   'Lat': 68.36,
#   'Lng': -133.71,
#   'Max Temp': 51.8,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': 1533141960},
#  {'City': 'buraydah',
#   'Lat': 26.33,
#   'Lng': 43.97,
#   'Max Temp': 102.2,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'SA',
#   'Date': 1533139200},
#  {'City': 'tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.69,
#   'Max Temp': 44.02,
#   'Humidity': 100,
#   'Cloudiness': 56,
#   'Wind Speed': 8.21,
#   'Country': 'NZ',
#   'Date': 1533143160},
#  {'City': 'presidencia roque saenz pena',
#   'Lat': -26.79,
#   'Lng': -60.44,
#   'Max Temp': 64.63,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 7.2,
#   'Country': 'AR',
#   'Date': 1533143160},
#  {'City': 'swellendam',
#   'Lat': -34.02,
#   'Lng': 20.44,
#   'Max Temp': 62.6,
#   'Humidity': 51,
#   'Cloudiness': 76,
#   'Wind Speed': 8.05,
#   'Country': 'ZA',
#   'Date': 1533139200},
#  {'City': 'yanaul',
#   'Lat': 56.27,
#   'Lng': 54.93,
#   'Max Temp': 67.87,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 7.65,
#   'Country': 'RU',
#   'Date': 1533143161},
#  {'City': 'yatou',
#   'Lat': 3.63,
#   'Lng': 9.81,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'CM',
#   'Date': 1533139200},
#  {'City': 'pochutla',
#   'Lat': 15.74,
#   'Lng': -96.47,
#   'Max Temp': 87.8,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 5.41,
#   'Country': 'MX',
#   'Date': 1533141900},
#  {'City': 'henties bay',
#   'Lat': -22.12,
#   'Lng': 14.28,
#   'Max Temp': 54.82,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 7.76,
#   'Country': 'NA',
#   'Date': 1533143163},
#  {'City': 'karanja',
#   'Lat': 20.48,
#   'Lng': 77.49,
#   'Max Temp': 76.42,
#   'Humidity': 81,
#   'Cloudiness': 92,
#   'Wind Speed': 12.57,
#   'Country': 'IN',
#   'Date': 1533143163},
#  {'City': 'adrar',
#   'Lat': 27.87,
#   'Lng': -0.29,
#   'Max Temp': 104,
#   'Humidity': 13,
#   'Cloudiness': 40,
#   'Wind Speed': 27.51,
#   'Country': 'DZ',
#   'Date': 1533139200},
#  {'City': 'tostedt',
#   'Lat': 53.28,
#   'Lng': 9.71,
#   'Max Temp': 84.2,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'DE',
#   'Date': 1533140400},
#  {'City': 'fort nelson',
#   'Lat': 58.81,
#   'Lng': -122.69,
#   'Max Temp': 66.2,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'valparaiso',
#   'Lat': 41.47,
#   'Lng': -87.06,
#   'Max Temp': 80.6,
#   'Humidity': 47,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': 1533141900},
#  {'City': 'bilma',
#   'Lat': 18.69,
#   'Lng': 12.92,
#   'Max Temp': 98.11,
#   'Humidity': 22,
#   'Cloudiness': 80,
#   'Wind Speed': 5.97,
#   'Country': 'NE',
#   'Date': 1533143166},
#  {'City': 'tanete',
#   'Lat': -3.94,
#   'Lng': 119.78,
#   'Max Temp': 71.2,
#   'Humidity': 95,
#   'Cloudiness': 20,
#   'Wind Speed': 4.74,
#   'Country': 'ID',
#   'Date': 1533143166},
#  {'City': 'aykhal',
#   'Lat': 65.95,
#   'Lng': 111.51,
#   'Max Temp': 41.41,
#   'Humidity': 88,
#   'Cloudiness': 8,
#   'Wind Speed': 2.51,
#   'Country': 'RU',
#   'Date': 1533143166},
#  {'City': 'alofi',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 62.6,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Country': 'NU',
#   'Date': 1533139200},
#  {'City': 'anapskaya',
#   'Lat': 44.9,
#   'Lng': 37.38,
#   'Max Temp': 87.8,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 13.42,
#   'Country': 'RU',
#   'Date': 1533139200},
#  {'City': 'saint-philippe',
#   'Lat': 45.36,
#   'Lng': -73.48,
#   'Max Temp': 80.6,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': 1533141300},
#  {'City': 'matara',
#   'Lat': -13.74,
#   'Lng': -72.9,
#   'Max Temp': 56.53,
#   'Humidity': 46,
#   'Cloudiness': 48,
#   'Wind Speed': 2.51,
#   'Country': 'PE',
#   'Date': 1533143168},
#  {'City': 'gat',
#   'Lat': 14.69,
#   'Lng': -16.54,
#   'Max Temp': 83.44,
#   'Humidity': 74,
#   'Cloudiness': 88,
#   'Wind Speed': 15.03,
#   'Country': 'SN',
#   'Date': 1533143168},
#  {'City': 'domna',
#   'Lat': 51.9,
#   'Lng': 113.16,
#   'Max Temp': 60.8,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': 1533141000},
#  {'City': 'san juan',
#   'Lat': 14.6,
#   'Lng': 121.03,
#   'Max Temp': 82.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'PH',
#   'Date': 1533139200},
#  {'City': 'broken hill',
#   'Lat': -31.97,
#   'Lng': 141.45,
#   'Max Temp': 43.12,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 9.55,
#   'Country': 'AU',
#   'Date': 1533143170},
#  {'City': 'slupsk',
#   'Lat': 54.46,
#   'Lng': 17.03,
#   'Max Temp': 78.49,
#   'Humidity': 80,
#   'Cloudiness': 8,
#   'Wind Speed': 3.18,
#   'Country': 'PL',
#   'Date': 1533142979},
#  {'City': 'khatanga',
#   'Lat': 71.98,
#   'Lng': 102.47,
#   'Max Temp': 46.36,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.09,
#   'Country': 'RU',
#   'Date': 1533143170},
#  {'City': 'gamba',
#   'Lat': 28.28,
#   'Lng': 88.52,
#   'Max Temp': 34.66,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 2.95,
#   'Country': 'CN',
#   'Date': 1533143171},
#  {'City': 'itarema',
#   'Lat': -2.92,
#   'Lng': -39.92,
#   'Max Temp': 87.22,
#   'Humidity': 64,
#   'Cloudiness': 12,
#   'Wind Speed': 15.59,
#   'Country': 'BR',
#   'Date': 1533143171},
#  {'City': 'platteville',
#   'Lat': 42.73,
#   'Lng': -90.48,
#   'Max Temp': 82.4,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': 1533141300},
#  {'City': 'atar',
#   'Lat': 20.52,
#   'Lng': -13.05,
#   'Max Temp': 105.22,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 7.2,
#   'Country': 'MR',
#   'Date': 1533143172},
#  {'City': 'atagay',
#   'Lat': 55.1,
#   'Lng': 99.39,
#   'Max Temp': 56.62,
#   'Humidity': 97,
#   'Cloudiness': 48,
#   'Wind Speed': 2.62,
#   'Country': 'RU',
#   'Date': 1533143172},
#  {'City': 'evensk',
#   'Lat': 61.92,
#   'Lng': 159.24,
#   'Max Temp': 53.74,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 9.44,
#   'Country': 'RU',
#   'Date': 1533143173},
#  {'City': 'geraldton',
#   'Lat': 49.72,
#   'Lng': -86.95,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'pevek',
#   'Lat': 69.7,
#   'Lng': 170.27,
#   'Max Temp': 52.39,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 6.64,
#   'Country': 'RU',
#   'Date': 1533143173},
#  {'City': 'ocos',
#   'Lat': 14.51,
#   'Lng': -92.19,
#   'Max Temp': 91.4,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'GT',
#   'Date': 1533142800},
#  {'City': 'aklavik',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 4.63,
#   'Country': 'CA',
#   'Date': 1533141960},
#  {'City': 'hovd',
#   'Lat': 63.83,
#   'Lng': 10.7,
#   'Max Temp': 69.8,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'NO',
#   'Date': 1533140400},
#  {'City': 'natal',
#   'Lat': -5.81,
#   'Lng': -35.21,
#   'Max Temp': 81.28,
#   'Humidity': 69,
#   'Cloudiness': 92,
#   'Wind Speed': 14.58,
#   'Country': 'BR',
#   'Date': 1533143175},
#  {'City': 'mehamn',
#   'Lat': 71.03,
#   'Lng': 27.85,
#   'Max Temp': 80.6,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'NO',
#   'Date': 1533138600},
#  {'City': 'pangnirtung',
#   'Lat': 66.15,
#   'Lng': -65.72,
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'olinda',
#   'Lat': -2.03,
#   'Lng': -79.75,
#   'Max Temp': 81.82,
#   'Humidity': 83,
#   'Cloudiness': 64,
#   'Wind Speed': 4.52,
#   'Country': 'EC',
#   'Date': 1533143176},
#  {'City': 'ullal',
#   'Lat': 12.8,
#   'Lng': 74.85,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 3.4,
#   'Country': 'IN',
#   'Date': 1533141000},
#  {'City': 'bubaque',
#   'Lat': 11.28,
#   'Lng': -15.83,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'GW',
#   'Date': 1533139200},
#  {'City': 'krasnomayskiy',
#   'Lat': 55,
#   'Lng': 82.52,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': 1533141000},
#  {'City': 'kutum',
#   'Lat': 14.2,
#   'Lng': 24.66,
#   'Max Temp': 70.12,
#   'Humidity': 82,
#   'Cloudiness': 92,
#   'Wind Speed': 3.4,
#   'Country': 'SD',
#   'Date': 1533143177},
#  {'City': 'ambon',
#   'Lat': 47.55,
#   'Lng': -2.56,
#   'Max Temp': 75.2,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Country': 'FR',
#   'Date': 1533141000},
#  {'City': 'menongue',
#   'Lat': -14.66,
#   'Lng': 17.68,
#   'Max Temp': 66.16,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Country': 'AO',
#   'Date': 1533143178},
#  {'City': 'cayenne',
#   'Lat': 4.94,
#   'Lng': -52.33,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'GF',
#   'Date': 1533142800},
#  {'City': 'wairoa',
#   'Lat': -39.04,
#   'Lng': 177.43,
#   'Max Temp': 43.93,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 3.18,
#   'Country': 'NZ',
#   'Date': 1533143179},
#  {'City': 'bajil',
#   'Lat': 38.23,
#   'Lng': -2.07,
#   'Max Temp': 88.03,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 7.99,
#   'Country': 'ES',
#   'Date': 1533143179},
#  {'City': 'broome',
#   'Lat': 52.47,
#   'Lng': 1.45,
#   'Max Temp': 78.8,
#   'Humidity': 36,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'GB',
#   'Date': 1533140400},
#  {'City': 'pemba',
#   'Lat': -12.97,
#   'Lng': 40.52,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'MZ',
#   'Date': 1533139200},
#  {'City': 'praia da vitoria',
#   'Lat': 38.73,
#   'Lng': -27.07,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 4.97,
#   'Country': 'PT',
#   'Date': 1533139200},
#  {'City': 'yar-sale',
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 46.72,
#   'Humidity': 94,
#   'Cloudiness': 76,
#   'Wind Speed': 18.05,
#   'Country': 'RU',
#   'Date': 1533143180},
#  {'City': 'marabba',
#   'Lat': 12.35,
#   'Lng': 32.18,
#   'Max Temp': 82.36,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 4.74,
#   'Country': 'SD',
#   'Date': 1533143180},
#  {'City': 'opoczno',
#   'Lat': 51.38,
#   'Lng': 20.29,
#   'Max Temp': 79.57,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3.51,
#   'Country': 'PL',
#   'Date': 1533143181},
#  {'City': 'winnemucca',
#   'Lat': 40.97,
#   'Lng': -117.74,
#   'Max Temp': 92.62,
#   'Humidity': 13,
#   'Cloudiness': 8,
#   'Wind Speed': 4.18,
#   'Country': 'US',
#   'Date': 1533143181},
#  {'City': 'vieux-habitants',
#   'Lat': 16.06,
#   'Lng': -61.77,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'GP',
#   'Date': 1533141000},
#  {'City': 'orlik',
#   'Lat': 52.51,
#   'Lng': 99.83,
#   'Max Temp': 42.22,
#   'Humidity': 89,
#   'Cloudiness': 12,
#   'Wind Speed': 1.72,
#   'Country': 'RU',
#   'Date': 1533143181},
#  {'City': 'bossangoa',
#   'Lat': 6.5,
#   'Lng': 17.45,
#   'Max Temp': 67.6,
#   'Humidity': 99,
#   'Cloudiness': 92,
#   'Wind Speed': 7.09,
#   'Country': 'CF',
#   'Date': 1533143182},
#  {'City': 'bubanza',
#   'Lat': -3.08,
#   'Lng': 29.39,
#   'Max Temp': 59.59,
#   'Humidity': 99,
#   'Cloudiness': 56,
#   'Wind Speed': 0.16,
#   'Country': 'BI',
#   'Date': 1533143182},
#  {'City': 'pangkalanbuun',
#   'Lat': -2.68,
#   'Lng': 111.62,
#   'Max Temp': 72.37,
#   'Humidity': 94,
#   'Cloudiness': 36,
#   'Wind Speed': 3.4,
#   'Country': 'ID',
#   'Date': 1533143182},
#  {'City': 'berlevag',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Max Temp': 84.2,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'NO',
#   'Date': 1533138600},
#  {'City': 'sandy point',
#   'Lat': 43.71,
#   'Lng': -65.32,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'isla mujeres',
#   'Lat': 21.23,
#   'Lng': -86.73,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 18.34,
#   'Country': 'MX',
#   'Date': 1533142200},
#  {'City': 'acapulco',
#   'Lat': 16.86,
#   'Lng': -99.88,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'MX',
#   'Date': 1533142260},
#  {'City': 'okhotsk',
#   'Lat': 59.36,
#   'Lng': 143.24,
#   'Max Temp': 53.11,
#   'Humidity': 100,
#   'Cloudiness': 32,
#   'Wind Speed': 2.51,
#   'Country': 'RU',
#   'Date': 1533143184},
#  {'City': 'mandurah',
#   'Lat': -32.55,
#   'Lng': 115.7,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Country': 'AU',
#   'Date': 1533141360},
#  {'City': 'guilin',
#   'Lat': 25.28,
#   'Lng': 110.29,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Country': 'CN',
#   'Date': 1533139200},
#  {'City': 'kanonji',
#   'Lat': 34.12,
#   'Lng': 133.65,
#   'Max Temp': 77.77,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.4,
#   'Country': 'JP',
#   'Date': 1533142949},
#  {'City': 'azangaro',
#   'Lat': -14.91,
#   'Lng': -70.2,
#   'Max Temp': 56.26,
#   'Humidity': 41,
#   'Cloudiness': 48,
#   'Wind Speed': 3.18,
#   'Country': 'PE',
#   'Date': 1533143185},
#  {'City': 'naze',
#   'Lat': 5.43,
#   'Lng': 7.07,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'NG',
#   'Date': 1533139200},
#  {'City': 'kawambwa',
#   'Lat': -9.8,
#   'Lng': 29.07,
#   'Max Temp': 67.96,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'ZM',
#   'Date': 1533143186},
#  {'City': 'sept-iles',
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 75.2,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'dawson creek',
#   'Lat': 55.76,
#   'Lng': -120.23,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 3.74,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'sovetskiy',
#   'Lat': 56.76,
#   'Lng': 48.47,
#   'Max Temp': 68.5,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 5.53,
#   'Country': 'RU',
#   'Date': 1533143187},
#  {'City': 'airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 63.19,
#   'Humidity': 91,
#   'Cloudiness': 24,
#   'Wind Speed': 1.72,
#   'Country': 'TL',
#   'Date': 1533143187},
#  {'City': 'santa maria',
#   'Lat': -29.69,
#   'Lng': -53.81,
#   'Max Temp': 55.4,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 12.75,
#   'Country': 'BR',
#   'Date': 1533139200},
#  {'City': 'yola',
#   'Lat': 9.26,
#   'Lng': 12.45,
#   'Max Temp': 70.84,
#   'Humidity': 99,
#   'Cloudiness': 88,
#   'Wind Speed': 2.51,
#   'Country': 'NG',
#   'Date': 1533143190},
#  {'City': 'kirakira',
#   'Lat': -10.46,
#   'Lng': 161.92,
#   'Max Temp': 80.56,
#   'Humidity': 100,
#   'Cloudiness': 68,
#   'Wind Speed': 17.05,
#   'Country': 'SB',
#   'Date': 1533143191},
#  {'City': 'varena',
#   'Lat': 54.21,
#   'Lng': 24.57,
#   'Max Temp': 80.6,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'LT',
#   'Date': 1533142200},
#  {'City': 'padang',
#   'Lat': -0.92,
#   'Lng': 100.36,
#   'Max Temp': 80.11,
#   'Humidity': 100,
#   'Cloudiness': 56,
#   'Wind Speed': 1.16,
#   'Country': 'ID',
#   'Date': 1533143191},
#  {'City': 'haines junction',
#   'Lat': 60.75,
#   'Lng': -137.51,
#   'Max Temp': 64.81,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 2.62,
#   'Country': 'CA',
#   'Date': 1533143192},
#  {'City': 'salaga',
#   'Lat': 8.55,
#   'Lng': -0.52,
#   'Max Temp': 88.3,
#   'Humidity': 52,
#   'Cloudiness': 80,
#   'Wind Speed': 5.64,
#   'Country': 'GH',
#   'Date': 1533143192},
#  {'City': 'port-gentil',
#   'Lat': -0.72,
#   'Lng': 8.78,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'GA',
#   'Date': 1533139200},
#  {'City': 'tiksi',
#   'Lat': 71.64,
#   'Lng': 128.87,
#   'Max Temp': 43.66,
#   'Humidity': 97,
#   'Cloudiness': 44,
#   'Wind Speed': 8.1,
#   'Country': 'RU',
#   'Date': 1533143193},
#  {'City': 'chuy',
#   'Lat': -33.69,
#   'Lng': -53.46,
#   'Max Temp': 52.21,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 9.1,
#   'Country': 'UY',
#   'Date': 1533143193},
#  {'City': 'isangel',
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 72.46,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 12.68,
#   'Country': 'VU',
#   'Date': 1533143193},
#  {'City': 'luanda',
#   'Lat': -8.83,
#   'Lng': 13.24,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'AO',
#   'Date': 1533139200},
#  {'City': 'yelizovo',
#   'Lat': 53.19,
#   'Lng': 158.38,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Date': 1533139200},
#  {'City': 'ternate',
#   'Lat': 14.29,
#   'Lng': 120.72,
#   'Max Temp': 82.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'PH',
#   'Date': 1533139200},
#  {'City': 'sheridan',
#   'Lat': 39.65,
#   'Lng': -105.03,
#   'Max Temp': 75.2,
#   'Humidity': 33,
#   'Cloudiness': 1,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1533141360},
#  {'City': 'lao cai',
#   'Lat': 22.48,
#   'Lng': 103.95,
#   'Max Temp': 68.32,
#   'Humidity': 96,
#   'Cloudiness': 80,
#   'Wind Speed': 1.5,
#   'Country': 'VN',
#   'Date': 1533143196},
#  {'City': 'ballina',
#   'Lat': 54.11,
#   'Lng': -9.15,
#   'Max Temp': 60.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'IE',
#   'Date': 1533141000},
#  {'City': 'rancho palos verdes',
#   'Lat': 33.75,
#   'Lng': -118.37,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 5,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': 1533139080},
#  {'City': 'novikovo',
#   'Lat': 45.05,
#   'Lng': 34.56,
#   'Max Temp': 74.89,
#   'Humidity': 82,
#   'Cloudiness': 24,
#   'Wind Speed': 6.42,
#   'Country': 'UA',
#   'Date': 1533143196},
#  {'City': 'dwarka',
#   'Lat': 28.58,
#   'Lng': 77.04,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'IN',
#   'Date': 1533141000},
#  {'City': 'yulara',
#   'Lat': -25.24,
#   'Lng': 130.99,
#   'Max Temp': 71.6,
#   'Humidity': 21,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'AU',
#   'Date': 1533142800},
#  {'City': 'voyvozh',
#   'Lat': 62.89,
#   'Lng': 54.96,
#   'Max Temp': 55.99,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 7.2,
#   'Country': 'RU',
#   'Date': 1533143197},
#  {'City': 'tual',
#   'Lat': -5.67,
#   'Lng': 132.75,
#   'Max Temp': 78.67,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 14.25,
#   'Country': 'ID',
#   'Date': 1533143197},
#  {'City': 'finschhafen',
#   'Lat': -6.6,
#   'Lng': 147.85,
#   'Max Temp': 70.75,
#   'Humidity': 97,
#   'Cloudiness': 12,
# ...
#   'Max Temp': 37.27,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 0.94,
#   'Country': 'IN',
#   'Date': 1533143266},
#  {'City': 'takaka',
#   'Lat': -40.86,
#   'Lng': 172.81,
#   'Max Temp': 49.42,
#   'Humidity': 100,
#   'Cloudiness': 80,
#   'Wind Speed': 6.2,
#   'Country': 'NZ',
#   'Date': 1533143266},
#  {'City': 'el alto',
#   'Lat': -16.5,
#   'Lng': -68.19,
#   'Max Temp': 57.2,
#   'Humidity': 24,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'BO',
#   'Date': 1533142800},
#  {'City': 'leh',
#   'Lat': 34.16,
#   'Lng': 77.58,
#   'Max Temp': 34.66,
#   'Humidity': 76,
#   'Cloudiness': 8,
#   'Wind Speed': 0.49,
#   'Country': 'IN',
#   'Date': 1533143267},
#  {'City': 'aksarka',
#   'Lat': 66.56,
#   'Lng': 67.8,
#   'Max Temp': 41.23,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 11.23,
#   'Country': 'RU',
#   'Date': 1533143267},
#  {'City': 'selfoss',
#   'Lat': 63.94,
#   'Lng': -21,
#   'Max Temp': 55.4,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'IS',
#   'Date': 1533141300},
#  {'City': 'kaohsiung',
#   'Lat': 22.62,
#   'Lng': 120.31,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'TW',
#   'Date': 1533139200},
#  {'City': 'souillac',
#   'Lat': 45.6,
#   'Lng': -0.6,
#   'Max Temp': 86,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Country': 'FR',
#   'Date': 1533141000},
#  {'City': 'alta floresta',
#   'Lat': -9.87,
#   'Lng': -56.08,
#   'Max Temp': 98.92,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 2.95,
#   'Country': 'BR',
#   'Date': 1533143268},
#  {'City': 'bonavista',
#   'Lat': 48.65,
#   'Lng': -53.11,
#   'Max Temp': 72.46,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 4.41,
#   'Country': 'CA',
#   'Date': 1533143269},
#  {'City': 'anloga',
#   'Lat': 5.79,
#   'Lng': 0.9,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Country': 'GH',
#   'Date': 1533139200},
#  {'City': 'niksar',
#   'Lat': 40.59,
#   'Lng': 36.95,
#   'Max Temp': 69.22,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 1.61,
#   'Country': 'TR',
#   'Date': 1533143270},
#  {'City': 'sisimiut',
#   'Lat': 66.94,
#   'Lng': -53.67,
#   'Max Temp': 41.5,
#   'Humidity': 99,
#   'Cloudiness': 92,
#   'Wind Speed': 2.51,
#   'Country': 'GL',
#   'Date': 1533143270},
#  {'City': 'bermeo',
#   'Lat': 43.42,
#   'Lng': -2.72,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'ES',
#   'Date': 1533141000},
#  {'City': 'libreville',
#   'Lat': 0.39,
#   'Lng': 9.45,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'GA',
#   'Date': 1533141000},
#  {'City': 'lamar',
#   'Lat': 38.09,
#   'Lng': -102.62,
#   'Max Temp': 75.2,
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 4.18,
#   'Country': 'US',
#   'Date': 1533138780},
#  {'City': 'bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 87.8,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 24.16,
#   'Country': 'BB',
#   'Date': 1533142800},
#  {'City': 'durban',
#   'Lat': 43.54,
#   'Lng': 0.58,
#   'Max Temp': 89.6,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'FR',
#   'Date': 1533141000},
#  {'City': 'harderwijk',
#   'Lat': 52.35,
#   'Lng': 5.63,
#   'Max Temp': 82.4,
#   'Humidity': 37,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'NL',
#   'Date': 1533140700},
#  {'City': 'tabas',
#   'Lat': 33.6,
#   'Lng': 56.92,
#   'Max Temp': 82.18,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'IR',
#   'Date': 1533143272},
#  {'City': 'waitati',
#   'Lat': -45.75,
#   'Lng': 170.57,
#   'Max Temp': 34.75,
#   'Humidity': 88,
#   'Cloudiness': 88,
#   'Wind Speed': 1.61,
#   'Country': 'NZ',
#   'Date': 1533143272},
#  {'City': 'seoul',
#   'Lat': 37.57,
#   'Lng': 126.98,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'KR',
#   'Date': 1533141000},
#  {'City': 'moberly',
#   'Lat': 39.42,
#   'Lng': -92.44,
#   'Max Temp': 84.2,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': 1533141300},
#  {'City': 'eureka',
#   'Lat': 40.8,
#   'Lng': -124.16,
#   'Max Temp': 55.4,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': 1533141300},
#  {'City': 'iralaya',
#   'Lat': 15,
#   'Lng': -83.23,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'HN',
#   'Date': 1533142800},
#  {'City': 'togur',
#   'Lat': 58.36,
#   'Lng': 82.83,
#   'Max Temp': 48.52,
#   'Humidity': 71,
#   'Cloudiness': 48,
#   'Wind Speed': 5.75,
#   'Country': 'RU',
#   'Date': 1533143273},
#  {'City': 'helena',
#   'Lat': 46.59,
#   'Lng': -112.04,
#   'Max Temp': 77,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 3.4,
#   'Country': 'US',
#   'Date': 1533142380},
#  {'City': 'alice springs',
#   'Lat': -23.7,
#   'Lng': 133.88,
#   'Max Temp': 62.6,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'AU',
#   'Date': 1533142800},
#  {'City': 'emba',
#   'Lat': 34.81,
#   'Lng': 32.42,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'CY',
#   'Date': 1533141000},
#  {'City': 'gizo',
#   'Lat': 31.8,
#   'Lng': 34.94,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Country': 'IL',
#   'Date': 1533142200},
#  {'City': 'along',
#   'Lat': 28.17,
#   'Lng': 94.8,
#   'Max Temp': 68.14,
#   'Humidity': 96,
#   'Cloudiness': 92,
#   'Wind Speed': 1.61,
#   'Country': 'IN',
#   'Date': 1533143275},
#  {'City': 'grand-santi',
#   'Lat': 4.27,
#   'Lng': -54.38,
#   'Max Temp': 86.86,
#   'Humidity': 65,
#   'Cloudiness': 24,
#   'Wind Speed': 2.95,
#   'Country': 'GF',
#   'Date': 1533143276},
#  {'City': 'angoram',
#   'Lat': -4.06,
#   'Lng': 144.07,
#   'Max Temp': 74.62,
#   'Humidity': 99,
#   'Cloudiness': 20,
#   'Wind Speed': 2.39,
#   'Country': 'PG',
#   'Date': 1533143276},
#  {'City': 'buin',
#   'Lat': -33.73,
#   'Lng': -70.74,
#   'Max Temp': 55.4,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'CL',
#   'Date': 1533139200},
#  {'City': 'sisophon',
#   'Lat': 13.59,
#   'Lng': 102.97,
#   'Max Temp': 74.62,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 12.01,
#   'Country': 'KH',
#   'Date': 1533143276},
#  {'City': 'freeport',
#   'Lat': 26.54,
#   'Lng': -78.7,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'BS',
#   'Date': 1533139200},
#  {'City': 'vangaindrano',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp': 60.94,
#   'Humidity': 96,
#   'Cloudiness': 24,
#   'Wind Speed': 4.18,
#   'Country': 'MG',
#   'Date': 1533143277},
#  {'City': 'belmonte',
#   'Lat': 40.36,
#   'Lng': -7.35,
#   'Max Temp': 88.12,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 2.51,
#   'Country': 'PT',
#   'Date': 1533143190},
#  {'City': 'shiyan',
#   'Lat': 32.65,
#   'Lng': 110.78,
#   'Max Temp': 74.71,
#   'Humidity': 91,
#   'Cloudiness': 36,
#   'Wind Speed': 1.95,
#   'Country': 'CN',
#   'Date': 1533143278},
#  {'City': 'vagur',
#   'Lat': 61.47,
#   'Lng': -6.81,
#   'Max Temp': 54.37,
#   'Humidity': 95,
#   'Cloudiness': 24,
#   'Wind Speed': 17.49,
#   'Country': 'FO',
#   'Date': 1533143278},
#  {'City': 'monte alegre de sergipe',
#   'Lat': -10.03,
#   'Lng': -37.56,
#   'Max Temp': 84.07,
#   'Humidity': 48,
#   'Cloudiness': 32,
#   'Wind Speed': 11.68,
#   'Country': 'BR',
#   'Date': 1533143104},
#  {'City': 'vao',
#   'Lat': 59.1,
#   'Lng': 26.19,
#   'Max Temp': 75.61,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 3.62,
#   'Country': 'EE',
#   'Date': 1533143279},
#  {'City': 'asbestos',
#   'Lat': 45.78,
#   'Lng': -71.93,
#   'Max Temp': 78.8,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Country': 'CA',
#   'Date': 1533139200},
#  {'City': 'solnechnyy',
#   'Lat': 50.72,
#   'Lng': 136.64,
#   'Max Temp': 55.9,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Country': 'RU',
#   'Date': 1533143280},
#  {'City': 'toccoa',
#   'Lat': 34.58,
#   'Lng': -83.33,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': 1533141720},
#  {'City': 'challapata',
#   'Lat': -18.9,
#   'Lng': -66.78,
#   'Max Temp': 46.63,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'BO',
#   'Date': 1533143280},
#  {'City': 'ixtapa',
#   'Lat': 20.71,
#   'Lng': -105.21,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'MX',
#   'Date': 1533141900},
#  {'City': 'high rock',
#   'Lat': 26.63,
#   'Lng': -78.28,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'BS',
#   'Date': 1533139200},
#  {'City': 'talnakh',
#   'Lat': 69.49,
#   'Lng': 88.39,
#   'Max Temp': 43.93,
#   'Humidity': 73,
#   'Cloudiness': 68,
#   'Wind Speed': 17.72,
#   'Country': 'RU',
#   'Date': 1533143281},
#  {'City': 'khorixas',
#   'Lat': -20.37,
#   'Lng': 14.96,
#   'Max Temp': 63.64,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'NA',
#   'Date': 1533143282},
#  {'City': 'sistranda',
#   'Lat': 63.73,
#   'Lng': 8.83,
#   'Max Temp': 69.8,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Country': 'NO',
#   'Date': 1533140400},
#  {'City': 'raton',
#   'Lat': 36.9,
#   'Lng': -104.44,
#   'Max Temp': 77,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': 1533142380},
#  {'City': 'benguela',
#   'Lat': -12.58,
#   'Lng': 13.4,
#   'Max Temp': 66.79,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 4.52,
#   'Country': 'AO',
#   'Date': 1533143282},
#  {'City': 'itamaraca',
#   'Lat': -7.75,
#   'Lng': -34.83,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Country': 'BR',
#   'Date': 1533139200},
#  {'City': 'uray',
#   'Lat': 60.13,
#   'Lng': 64.8,
#   'Max Temp': 55.18,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 7.54,
#   'Country': 'RU',
#   'Date': 1533143283},
#  {'City': 'kijang',
#   'Lat': 35.24,
#   'Lng': 129.21,
#   'Max Temp': 84.2,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'KR',
#   'Date': 1533139200},
#  {'City': 'tamandare',
#   'Lat': -8.28,
#   'Lng': -70.75,
#   'Max Temp': 76.96,
#   'Humidity': 93,
#   'Cloudiness': 88,
#   'Wind Speed': 1.72,
#   'Country': 'BR',
#   'Date': 1533143283},
#  {'City': 'banda aceh',
#   'Lat': 5.56,
#   'Lng': 95.32,
#   'Max Temp': 75.34,
#   'Humidity': 97,
#   'Cloudiness': 44,
#   'Wind Speed': 3.18,
#   'Country': 'ID',
#   'Date': 1533143284},
#  {'City': 'turayf',
#   'Lat': 31.68,
#   'Lng': 38.65,
#   'Max Temp': 89.6,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 13.87,
#   'Country': 'SA',
#   'Date': 1533139200},
#  {'City': 'nuevitas',
#   'Lat': 21.55,
#   'Lng': -77.27,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'CU',
#   'Date': 1533142200},
#  {'City': 'hikari',
#   'Lat': 33.97,
#   'Lng': 131.95,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'JP',
#   'Date': 1533138900},
#  {'City': 'oranjestad',
#   'Lat': 12.52,
#   'Lng': -70.03,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 20.8,
#   'Country': 'AW',
#   'Date': 1533139200},
#  {'City': 'muhlhausen',
#   'Lat': 51.22,
#   'Lng': 10.45,
#   'Max Temp': 77,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'DE',
#   'Date': 1533140400},
#  {'City': 'luang prabang',
#   'Lat': 19.89,
#   'Lng': 102.14,
#   'Max Temp': 73.27,
#   'Humidity': 88,
#   'Cloudiness': 76,
#   'Wind Speed': 2.39,
#   'Country': 'LA',
#   'Date': 1533143285},
#  {'City': 'adamas',
#   'Lat': 36.73,
#   'Lng': 24.43,
#   'Max Temp': 84.2,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 17.22,
#   'Country': 'GR',
#   'Date': 1533142200},
#  {'City': 'mayumba',
#   'Lat': -3.44,
#   'Lng': 10.65,
#   'Max Temp': 69.31,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'GA',
#   'Date': 1533143286},
#  {'City': 'portobelo',
#   'Lat': 9.55,
#   'Lng': -79.65,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'PA',
#   'Date': 1533142800},
#  {'City': 'keuruu',
#   'Lat': 62.26,
#   'Lng': 24.71,
#   'Max Temp': 86,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'FI',
#   'Date': 1533140400},
#  {'City': 'nizhnyaya tura',
#   'Lat': 58.62,
#   'Lng': 59.87,
#   'Max Temp': 62.56,
#   'Humidity': 82,
#   'Cloudiness': 92,
#   'Wind Speed': 7.09,
#   'Country': 'RU',
#   'Date': 1533143287},
#  {'City': 'pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 74.17,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 8.55,
#   'Country': 'TO',
#   'Date': 1533143287},
#  {'City': 'la rioja',
#   'Lat': -29.41,
#   'Lng': -66.86,
#   'Max Temp': 56.53,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.08,
#   'Country': 'AR',
#   'Date': 1533143287},
#  {'City': 'saldanha',
#   'Lat': 41.42,
#   'Lng': -6.55,
#   'Max Temp': 87.94,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 3.18,
#   'Country': 'PT',
#   'Date': 1533143288},
#  {'City': 'tunduma',
#   'Lat': -9.31,
#   'Lng': 32.77,
#   'Max Temp': 66.43,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 7.99,
#   'Country': 'ZM',
#   'Date': 1533143288},
#  {'City': 'portland',
#   'Lat': 45.52,
#   'Lng': -122.67,
#   'Max Temp': 64.4,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': 1533142380},
#  {'City': 'sola',
#   'Lat': 58.89,
#   'Lng': 5.65,
#   'Max Temp': 71.6,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 13.87,
#   'Country': 'NO',
#   'Date': 1533140400},
#  {'City': 'batouri',
#   'Lat': 4.44,
#   'Lng': 14.36,
#   'Max Temp': 68.5,
#   'Humidity': 98,
#   'Cloudiness': 68,
#   'Wind Speed': 2.39,
#   'Country': 'CM',
#   'Date': 1533143290},
#  {'City': 'tatarsk',
#   'Lat': 55.22,
#   'Lng': 75.96,
#   'Max Temp': 51.76,
#   'Humidity': 87,
#   'Cloudiness': 44,
#   'Wind Speed': 3.51,
#   'Country': 'RU',
#   'Date': 1533143290},
#  {'City': 'balaguer',
#   'Lat': 41.79,
#   'Lng': 0.81,
#   'Max Temp': 88.84,
#   'Humidity': 32,
#   'Cloudiness': 12,
#   'Wind Speed': 2.17,
#   'Country': 'ES',
#   'Date': 1533143290},
#  {'City': 'arona',
#   'Lat': 45.76,
#   'Lng': 8.56,
#   'Max Temp': 91.4,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'IT',
#   'Date': 1533142200},
#  {'City': 'mongar',
#   'Lat': 27.28,
#   'Lng': 91.24,
#   'Max Temp': 68.68,
#   'Humidity': 98,
#   'Cloudiness': 80,
#   'Wind Speed': 1.05,
#   'Country': 'BT',
#   'Date': 1533143291},
#  {'City': 'nishihara',
#   'Lat': 35.74,
#   'Lng': 139.53,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'JP',
#   'Date': 1533141000},
#  {'City': 'ignacio de la llave',
#   'Lat': 18.73,
#   'Lng': -95.98,
#   'Max Temp': 87.8,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'MX',
#   'Date': 1533141600},
#  {'City': 'turiacu',
#   'Lat': -5.01,
#   'Lng': -63,
#   'Max Temp': 82.09,
#   'Humidity': 89,
#   'Cloudiness': 12,
#   'Wind Speed': 5.97,
#   'Country': 'BR',
#   'Date': 1533143291},
#  {'City': 'sijunjung',
#   'Lat': -0.69,
#   'Lng': 100.95,
#   'Max Temp': 69.13,
#   'Humidity': 96,
#   'Cloudiness': 76,
#   'Wind Speed': 1.39,
#   'Country': 'ID',
#   'Date': 1533143292},
#  {'City': 'xingcheng',
#   'Lat': 40.62,
#   'Lng': 120.71,
#   'Max Temp': 75.7,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Country': 'CN',
#   'Date': 1533143292},
#  {'City': 'puerto del rosario',
#   'Lat': 28.5,
#   'Lng': -13.86,
#   'Max Temp': 78.8,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 25.28,
#   'Country': 'ES',
#   'Date': 1533141000},
#  {'City': 'bishop auckland',
#   'Lat': 54.66,
#   'Lng': -1.68,
#   'Max Temp': 69.8,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'GB',
#   'Date': 1533140400},
#  {'City': 'gombe',
#   'Lat': 10.28,
#   'Lng': 11.17,
#   'Max Temp': 69.31,
#   'Humidity': 99,
#   'Cloudiness': 92,
#   'Wind Speed': 3.74,
#   'Country': 'NG',
#   'Date': 1533143293},
#  {'City': 'venice',
#   'Lat': 27.1,
#   'Lng': -82.45,
#   'Max Temp': 89.6,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 11.01,
#   'Country': 'US',
#   'Date': 1533141300},
#  {'City': 'vanimo',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 84.61,
#   'Humidity': 97,
#   'Cloudiness': 8,
#   'Wind Speed': 12.57,
#   'Country': 'PG',
#   'Date': 1533143294},
#  {'City': 'opuwo',
#   'Lat': -18.06,
#   'Lng': 13.84,
#   'Max Temp': 65.71,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 5.97,
#   'Country': 'NA',
#   'Date': 1533143102}]

# %%
# Assemble data into dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         rikitea          44      PF  1533143102        94 -23.12 -134.97
# 1        hermanus           0      ZA  1533143102        93 -34.42   19.24
# 2  cabo san lucas          20      MX  1533141900        49  22.89 -109.91
# 3           vaini          92      IN  1533143103        99  15.34   74.49
# 4           sitka           0      US  1533143103        51  37.17  -99.65
#
#    Max Temp  Wind Speed
# 0     76.42       17.49
# 1     45.01        2.62
# 2     93.20        4.70
# 3     69.31        6.20
# 4     85.24       10.45

# %%
# Remove any cities that have NaN values
city_data_df = city_data_df.dropna(how='any')

print(f"The data frame contains {len(city_data_df['City'])} unique cities.")
# Out:
# The data frame contains 569 unique cities.

# %%
plt.figure(figsize=(10,7))
plt.scatter(pd.to_numeric(city_data_df["Lat"]), pd.to_numeric(city_data_df["Max Temp"]))
plt.title("Max Temperature (F) vs. City Latitude on Aug 1, 2018", fontsize=20)
plt.ylabel("Max Temperature (F)", fontsize=14)
plt.xlabel("Latitude", fontsize=14)
plt.ylim(-100, 150)
plt.xlim(-100, 100)
plt.savefig("TempvsLat.png")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(pd.to_numeric(city_data_df["Lat"]), pd.to_numeric(city_data_df["Humidity"]))
plt.title("Humidity (%) vs. City Latitude on Aug 1, 2018", fontsize=20)
plt.ylabel("Humidity (%)", fontsize=14)
plt.xlabel("Latitude", fontsize=14)
plt.ylim(-20, 120)
plt.xlim(-100, 100)
plt.savefig("HumidvsLat.png")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(pd.to_numeric(city_data_df["Lat"]), pd.to_numeric(city_data_df["Cloudiness"]))
plt.title("Cloudiness (%) vs. City Latitude on Aug 1, 2018", fontsize=20)
plt.ylabel("Cloudiness (%)", fontsize=14)
plt.xlabel("Latitude", fontsize=14)
plt.ylim(-20, 120)
plt.xlim(-100, 100)
plt.savefig("CloudvsLat.png")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(pd.to_numeric(city_data_df["Lat"]), pd.to_numeric(city_data_df["Wind Speed"]))
plt.title("Wind Speed (mph) vs. City Latitude on Aug 1, 2018", fontsize=20)
plt.ylabel("Wind Speed (mph)", fontsize=14)
plt.xlabel("Latitude", fontsize=14)
plt.ylim(-5, 50)
plt.xlim(-100, 100)
plt.savefig("WindvsLat.png")
plt.show()

# %%
city_data_df.to_csv("WeatherPy.csv")

# %%
plt.figure(figsize=(10,7))
temperatures = pd.to_numeric(city_data_df["Max Temp"])
plt.scatter(pd.to_numeric(city_data_df["Lng"]), pd.to_numeric(city_data_df["Lat"]), c=temperatures, cmap='coolwarm')
plt.title("Longitude vs. Latitude Weather Map", fontsize=20)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.ylim(-90, 90)
plt.xlim(-180, 180)
plt.savefig("heatmap.png")
plt.show()

# %% [markdown]
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
#
# Temperature (F) vs. Latitude
# Humidity (%) vs. Latitude
# Cloudiness (%) vs. Latitude
# Wind Speed (mph) vs. Latitude
#
#
# Your final notebook must:
#
#
# Randomly select at least 500 unique (non-repeat) cities based on latitude and longitude.
# Perform a weather check on each of the cities using a series of successive API calls.
# Include a print log of each city as it's being processed with the city number and city name.
# Save both a CSV of all data retrieved and png images for each scatter plot.
#
#
# As final considerations:
#
#
# You must complete your analysis using a Jupyter notebook.
# You must use the Matplotlib or Pandas plotting libraries.
# You must include a written description of three observable trends based on the data.
# You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
# See Example Solution for a reference on expected format.

# %% [markdown]
# # Observable trends

# %% [markdown]
# 1. There appears to be a parabolic association between city latitude and city temperature. That is to say, the cities located on the extremes of latitude (-90 to +90) tend to be lower in temperature, whereas the cities located near 0 latitude tend to be higher in temperature.
#
# 2. There does not appear to be strong correlation between wind speed or humidity and latitude. There is probably some association on some level, whether more granular or more course, but it is not apparent (if any) at the current level. Interestingly, humidity vs. latitude and wind speed vs. latitude plots almost appear to be mirror images of each other. It would be possible to determine whether the highest density points on the respective plots correspond to the same cities.
#
# 3. Another observable trend is cloudiness vs. latitude. This is a very interesting chart because it appears to have distinct periodicity interposed with randomness. I am not sure how precise the determination of cloudiness is made, but if it is "binned", it could explain the plot to an extent. But what is more likely occurring is a representation of true meteorlogical phenomena of nonlinear phase the transitions of cloud formation between areas of higher density and lower density which results in large "wavelike" regions of clouds.
